# %% [markdown]
# <a href="https://colab.research.google.com/github/apodvoisky/DLS2023/blob/hw-07/hw_kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание. Решение конкурса на kaggle.com
#
# Это домашнее задание посвящено полноценному решению задачи машинного обучения.

# %% [markdown]
# Есть две части этого домашнего задания:
#
# ### Отправить ваши предсказания в Stepik.
# За прохождение определенных порогов будут начисляться баллы. Эта часть оценивается из 5 баллов.
#
# 1) $1.00 \geqslant score \geqslant 0.84$ --- 5 баллов
#
# 2) $0.84 > score \geqslant 0.77$ --- 4 балла
#
# 3) $0.77 > score \geqslant 0.70$ --- 3 балла
#
# 4) $0.70 > score \geqslant 0.65$ --- 2 балла
#
# 5) $0.65 > score \geqslant 0.6$ --- 1 балл
#
# 6) $0.60 > score$ --- 0 баллов
#
# Для этого мы предварительно разделили данные в задании на две части.
# * `train.csv`. На этом наборе данных вам необходимо создать и обучить модель. Подробное описание файла есть в ноутбуке.
# * `test.csv`. В каждой строчке файла `test.csv` указаны признаки тестовых объектов. Предсказания для этого набора необходимо записать в файл submission.csv и сдать в соответствующий шаг на Stepik. Количество попыток ограничено 100 штук.
#
# Отправлять в Stepik вы будете файл с ответами `my_submission.csv`. В этом файле вам необходимо для каждого объекта из датасета предсказать вероятность класса 1. Мы подготовили для вас файл с примером посылки `submission.csv`. Ваш файл должен быть оформлен таким же образом. В ноутбуке есть пример оформления файла посылки. Для отправки файла с предсказаниями на Stepik есть отдельный шаг.
#
# ### Сделать полноценный отчет о вашей работе.
# Опишите, как вы обработали данные, какие модели попробовали и какие результаты получились (максимум 10 баллов). За каждую выполненную часть будет начислено определенное количество баллов. В этом пункте вам необходимо отправить файл в формате .ipynb на Stepik --- для этого в домашнем задании есть отдельный шаг. Этот пункт оценивается из 10 баллов.
#
# **Вторая часть будет проверяться в формате peer-review. Т.е. вашу посылку на Stepik будут проверять 3 других студента, и медианное значение их оценок будет выставлено. Чтобы получить баллы, вам также нужно будет проверить трех других учеников. Это станет доступно после того, как вы сдадите задание сами.**
#
# ### Контест на Kaggle
# Для вашего удобства мы подготовили [контест на Kaggle](https://www.kaggle.com/c/advanced-dls-spring-2021/). Тестирующая система на Kaggle выдает те же баллы, что и Stepik. Мы рекомендуем в качестве основной тестирующей системы использовать именно Kaggle, а затем сдать лучшую посылку на Stepik. Так вы привыкните работать с Kaggle.
#
# Проблема для российских пользователей Kaggle заключается в том, что подтверждение аккаунта по номеру телефона работает с перебоями или не работает вообще. Без подтвержденного номера телефона вы не сможете совершать посылки в kaggle. Если у вас возникла такая проблема, мы советуем следующие шаги:
# * Попробовать зарегистрировать аккаунт с аутентификацией через gmail. В таком случае, аккаунт должен работать без подтверждения номера телефона.
# * Если у вас есть не российский номер, используйте его для верификации аккаунта.
# * Если на номер телефона не приходит смс для верификации аккаунта, обратитесь в службу поддержки kaggle. Они с переменным успехом умеют подтверждать аккаунты вручную.
# * Если все же подтвердить аккаунт и получить доступ к сдаче заданий не удалось, используйте только сдачу в Stepik.
#
# ### Несколько замечаний по выполнению работы
# * Во всех пунктах указания это минимальный набор вещей, которые стоит сделать. Если вы можете сделать какой-то шаг лучше или добавить что-то свое --- дерзайте!
# * Пожалуйста, перед сдачей ноутбука убедитесь, что работа чистая и понятная. Это значительно облегчит проверку и повысит ваши ожидаемые баллы.
# * Если у вас будут проблемы с решением или хочется совета, то пишите в наш чат в телеграме.
#
#
# Данные: [train.csv](https://drive.google.com/file/d/1ERwQ5odiK1Zvi1LtjpkzCMUswYsAX8_K/view?usp=share_link),
# [test.csv](https://drive.google.com/file/d/1fGw_-RFwvn_LEdt91Jq-7A-wzG6mmH8r/view?usp=share_link), [submission.csv](https://drive.google.com/file/d/199Mt4OYZNaelT83U-HGDsEYs2YcUGQ6y/view?usp=share_link).
#
# Если ссылки на данные не работают, их можно скачать [на Kaggle](https://www.kaggle.com/competitions/advanced-dls-spring-2021/data).

# %% [markdown]
# # Как проверять?
#
# Ставьте полный балл, если выполнены все рекомендации или сделано что-то более интересное и сложное. За каждый отсустствующий пункт из рекомендации снижайте 1 балл.
#
# **Если решение верное, но не удовлетворяет вашим эстетическим предпочтениям, за это баллы снижать не нужно.**

# %% [markdown]
# # Метрика
#
# Перед решением любой задачи важно понимать, как будет оцениваться ваше решение. В данном случае мы используем стандартную для задачи классификации метрику ROC-AUC. Ее можно вычислить, используя только предсказанные вероятности и истинные классы без конкретного порога классификации + она раотает даже если классы в данных сильно несбалансированны (примеров одного класса в десятки раз больше примеров длугого). Именно поэтому она очень удобна для соревнований.
#
# Посчитать ее легко:

# %%
from sklearn.metrics import roc_auc_score

y_true = [
    0,
    1,
    1,
    0,
    1
]

y_predictions = [
    0.1,
    0.9,
    0.7,
    0.6,
    0.61
]

roc_auc_score(y_true, y_predictions)
# Out:
# 1.0

# %% [markdown]
# # Первая часть. Исследование

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Загрузка данных (2 балла)
#
# 1) Посмотрите на случайные строчки.
#
# 2) Посмотрите, есть ли в датасете незаполненные значения (nan'ы) с помощью data.isna() или data.info() и, если нужно, замените их на что-то. Будет хорошо, если вы построите табличку с количеством nan в каждой колонке.

# %%
# !gdown 1ERwQ5odiK1Zvi1LtjpkzCMUswYsAX8_K  # train.csv
# !gdown 1fGw_-RFwvn_LEdt91Jq-7A-wzG6mmH8r  # test.csv
# !gdown 199Mt4OYZNaelT83U-HGDsEYs2YcUGQ6y  # submission.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ERwQ5odiK1Zvi1LtjpkzCMUswYsAX8_K
# To: /content/train.csv
# 100% 664k/664k [00:00<00:00, 114MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1fGw_-RFwvn_LEdt91Jq-7A-wzG6mmH8r
# To: /content/test.csv
# 100% 218k/218k [00:00<00:00, 95.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=199Mt4OYZNaelT83U-HGDsEYs2YcUGQ6y
# To: /content/submission.csv
# 100% 14.7k/14.7k [00:00<00:00, 41.7MB/s]

# %%
data = pd.read_csv('./train.csv')

# %%
# Для вашего удобства списки с именами разных колонок

# Числовые признаки
num_cols = [
    'ClientPeriod',
    'MonthlySpending',
    'TotalSpent'
]

# Категориальные признаки
cat_cols = [
    'Sex',
    'IsSeniorCitizen',
    'HasPartner',
    'HasChild',
    'HasPhoneService',
    'HasMultiplePhoneNumbers',
    'HasInternetService',
    'HasOnlineSecurityService',
    'HasOnlineBackup',
    'HasDeviceProtection',
    'HasTechSupportAccess',
    'HasOnlineTV',
    'HasMovieSubscription',
    'HasContractPhone',
    'IsBillingPaperless',
    'PaymentMethod'
]

feature_cols = num_cols + cat_cols
target_col = 'Churn'

# %%
#1) Посмотрите на случайные строчки.
data.sample(n=5)

#2) Посмотрите, есть ли в датасете незаполненные значения (nan'ы) с помощью
#data.isna() или data.info() и, если нужно, замените их на что-то. Будет хорошо,
#если вы построите табличку с количеством nan в каждой колонке.

data.info()
data.shape

#Незаполненные значения отсутствуют
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5282 entries, 0 to 5281
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ClientPeriod              5282 non-null   int64
#  1   MonthlySpending           5282 non-null   float64
#  2   TotalSpent                5282 non-null   object
#  3   Sex                       5282 non-null   object
#  4   IsSeniorCitizen           5282 non-null   int64
#  5   HasPartner                5282 non-null   object
#  6   HasChild                  5282 non-null   object
#  7   HasPhoneService           5282 non-null   object
#  8   HasMultiplePhoneNumbers   5282 non-null   object
#  9   HasInternetService        5282 non-null   object
#  10  HasOnlineSecurityService  5282 non-null   object
#  11  HasOnlineBackup           5282 non-null   object
#  12  HasDeviceProtection       5282 non-null   object
#  13  HasTechSupportAccess      5282 non-null   object
#  14  HasOnlineTV               5282 non-null   object
#  15  HasMovieSubscription      5282 non-null   object
#  16  HasContractPhone          5282 non-null   object
#  17  IsBillingPaperless        5282 non-null   object
#  18  PaymentMethod             5282 non-null   object
#  19  Churn                     5282 non-null   int64
# dtypes: float64(1), int64(3), object(16)
# memory usage: 825.4+ KB
# (5282, 20)

# %% [markdown]
# ## Анализ данных (3 балла)
#
# 1) Для численных призанков постройте гистограмму (*plt.hist(...)*) или boxplot (*plt.boxplot(...)*). Для категориальных посчитайте количество каждого значения для каждого признака. Для каждой колонки надо сделать *data.value_counts()* и построить bar диаграммы *plt.bar(...)* или круговые диаграммы *plt.pie(...)* (хорошо, елси вы сможете это сделать на одном гарфике с помощью *plt.subplots(...)*).
#
# 2) Посмотрите на распределение целевой переменной и скажите, являются ли классы несбалансированными.
#
# 3) (Если будет желание) Поиграйте с разными библиотеками для визуализации - *sns*, *pandas_visual_analysis*, etc.
#
# Второй пункт очень важен, потому что существуют задачи классификации с несбалансированными классами. Например, это может значить, что в датасете намного больше примеров 0 класса. В таких случаях нужно 1) не использовать accuracy как метрику 2) использовать методы борьбы с imbalanced dataset (обычно если датасет сильно несбалансирован, т.е. класса 1 в 20 раз меньше класса 0).

# %%
#1) Для численных призанков постройте гистограмму (plt.hist(...)) или
#boxplot (plt.boxplot(...)). Для категориальных посчитайте количество
#каждого значения для каждого признака. Для каждой колонки надо сделать
#data.value_counts() и построить bar диаграммы plt.bar(...) или круговые
#диаграммы plt.pie(...) (хорошо, елси вы сможете это сделать на одном
#графике с помощью plt.subplots(...)).

settings = {
    "bins": 100,
    "plot_size" : {"width": 7, "height": 5},
}

plt.figure(
    figsize=(settings["plot_size"]["width"], settings["plot_size"]["height"]))

for i, feature in enumerate(num_cols):
    plt.subplot(len(num_cols), 1, i + 1)
    plt.hist(data[feature], bins=settings["bins"])
    plt.xlabel(feature)
    plt.ylabel('Частота')
    plt.title(f'Гистограмма для {feature}')

plt.tight_layout()
plt.show()

# %%
settings = {
    "bins": 100,
    "plot_size" : {"width": 12, "height": 30},
}

plt.figure(
    figsize=(settings["plot_size"]["width"], settings["plot_size"]["height"]))


for i, col in enumerate(cat_cols):
    plt.subplot(len(cat_cols), 3, i + 1)
    value_counts = data[col].value_counts()
    labels = value_counts.index
    sizes = value_counts.values
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=60)
    plt.title(f'Распределение {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# (Дополнительно) Если вы нашли какие-то ошибки в данных или выбросы, то можете их убрать. Тут можно поэксперементировать с обработкой данных как угодно, но не за баллы.

# %%
data["TotalSpent"] = pd.to_numeric(data["TotalSpent"], errors="coerce")

# %%
#Удаляем записи с пустыми TotalSpent
data.drop(data[data['TotalSpent'].isna()].index, inplace=True)

# %% [markdown]
# ## Применение линейных моделей (3 балла)
#
# 1) Обработайте данные для того, чтобы к ним можно было применить LogisticRegression. Т.е. отнормируйте числовые признаки, а категориальные закодируйте с помощью one-hot-encoding'а.
#
# 2) С помощью кроссвалидации или разделения на train/valid выборку протестируйте разные значения гиперпараметра C и выберите лучший (можно тестировать С=100, 10, 1, 0.1, 0.01, 0.001) по метрике ROC-AUC.
#
# Если вы разделяете на train/valid, то используйте LogisticRegressionCV. Он сам при вызове .fit() подберет параметр С. (не забудьте передать scroing='roc_auc', чтобы при кроссвалидации сравнивались значения этой метрики, и refit=True, чтобы при потом модель обучилась на всем датасете с лучшим параметром C).
#
#
# (более сложный вариант) Если вы будете использовать кроссвалидацию, то преобразования данных и LogisticRegression нужно соединить в один Pipeline с помощью make_pipeline, как это делалось во втором семинаре. Потом pipeline надо передать в GridSearchCV. Для one-hot-encoding'a можно испльзовать комбинацию LabelEncoder + OneHotEncoder (сначала превращаем строчки в числа, а потом числа првращаем в one-hot вектора.)

# %%
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder, OneHotEncoder
from sklearn.pipeline import make_pipeline

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder())
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, num_cols),
        ('cat', categorical_transformer, cat_cols)
    ])

pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

X = pipeline.fit_transform(data.drop(columns=[target_col]))
y = data[target_col]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score


C_values = [100, 10, 1, 0.1, 0.01, 0.001]
roc_auc_scores = {}

for C in C_values:
    model = LogisticRegression(C=C)
    cv_scores = cross_val_score(model, X, y, cv=5, scoring='roc_auc')
    roc_auc_scores[C] = cv_scores.mean()


best_C = max(roc_auc_scores, key=roc_auc_scores.get)

print("Результаты кросс-валидации:")
for C, roc_auc in roc_auc_scores.items():
    print(f"C = {C}: ROC-AUC = {roc_auc}")

print(f"Лучший C: {best_C} с ROC-AUC = {roc_auc_scores[best_C]}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Результаты кросс-валидации:
# C = 100: ROC-AUC = 0.8448208899368537
# C = 10: ROC-AUC = 0.8448265075092574
# C = 1: ROC-AUC = 0.8447152485602236
# C = 0.1: ROC-AUC = 0.8438174042185068
# C = 0.01: ROC-AUC = 0.8412947046859791
# C = 0.001: ROC-AUC = 0.8372018918620163
# Лучший C: 10 с ROC-AUC = 0.8448265075092574

# %%
model = LogisticRegression()
pipeline = make_pipeline(preprocessor, model)
param_grid = {'logisticregression__C': [100, 10, 1, 0.1, 0.01, 0.001]}
grid_search = GridSearchCV(pipeline, param_grid, scoring='roc_auc', cv=10)
grid_search.fit(data.drop(target_col, axis=1), data[target_col])
print("Лучший параметр C:", grid_search.best_params_)
print("Лучший ROC-AUC:", grid_search.best_score_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Лучший параметр C: {'logisticregression__C': 10}
# Лучший ROC-AUC: 0.8446241270756658

# %%
grid_search.__dict__
# Out:
# {'scoring': 'roc_auc',
#  'estimator': Pipeline(steps=[('columntransformer',
#                   ColumnTransformer(transformers=[('num',
#                                                    Pipeline(steps=[('scaler',
#                                                                     StandardScaler())]),
#                                                    ['ClientPeriod',
#                                                     'MonthlySpending',
#                                                     'TotalSpent']),
#                                                   ('cat',
#                                                    Pipeline(steps=[('onehot',
#                                                                     OneHotEncoder())]),
#                                                    ['Sex', 'IsSeniorCitizen',
#                                                     'HasPartner', 'HasChild',
#                                                     'HasPhoneService',
#                                                     'HasMultiplePhoneNumbers',
#                                                     'HasInternetService',
#                                                     'HasOnlineSecurityService',
#                                                     'HasOnlineBackup',
#                                                     'HasDeviceProtection',
#                                                     'HasTechSupportAccess',
#                                                     'HasOnlineTV',
#                                                     'HasMovieSubscription',
#                                                     'HasContractPhone',
#                                                     'IsBillingPaperless',
#                                                     'PaymentMethod'])])),
#                  ('logisticregression', LogisticRegression())]),
#  'n_jobs': None,
#  'refit': True,
#  'cv': 10,
#  'verbose': 0,
#  'pre_dispatch': '2*n_jobs',
#  'error_score': nan,
#  'return_train_score': False,
#  'param_grid': {'logisticregression__C': [100, 10, 1, 0.1, 0.01, 0.001]},
#  'multimetric_': False,
#  'best_index_': 1,
#  'best_score_': 0.8446241270756658,
#  'best_params_': {'logisticregression__C': 10},
#  'best_estimator_': Pipeline(steps=[('columntransformer',
#                   ColumnTransformer(transformers=[('num',
#                                                    Pipeline(steps=[('scaler',
#                                                                     StandardScaler())]),
#                                                    ['ClientPeriod',
#                                                     'MonthlySpending',
#                                                     'TotalSpent']),
#                                                   ('cat',
#                                                    Pipeline(steps=[('onehot',
#                                                                     OneHotEncoder())]),
#                                                    ['Sex', 'IsSeniorCitizen',
#                                                     'HasPartner', 'HasChild',
#                                                     'HasPhoneService',
#                                                     'HasMultiplePhoneNumbers',
#                                                     'HasInternetService',
#                                                     'HasOnlineSecurityService',
#                                                     'HasOnlineBackup',
#                                                     'HasDeviceProtection',
#                                                     'HasTechSupportAccess',
#                                                     'HasOnlineTV',
#                                                     'HasMovieSubscription',
#                                                     'HasContractPhone',
#                                                     'IsBillingPaperless',
#                                                     'PaymentMethod'])])),
#                  ('logisticregression', LogisticRegression(C=10))]),
#  'refit_time_': 0.11027812957763672,
#  'feature_names_in_': array(['ClientPeriod', 'MonthlySpending', 'TotalSpent', 'Sex',
#         'IsSeniorCitizen', 'HasPartner', 'HasChild', 'HasPhoneService',
#         'HasMultiplePhoneNumbers', 'HasInternetService',
#         'HasOnlineSecurityService', 'HasOnlineBackup',
#         'HasDeviceProtection', 'HasTechSupportAccess', 'HasOnlineTV',
#         'HasMovieSubscription', 'HasContractPhone', 'IsBillingPaperless',
#         'PaymentMethod'], dtype=object),
#  'scorer_': make_scorer(roc_auc_score, needs_threshold=True),
#  'cv_results_': {'mean_fit_time': array([0.1091331 , 0.259097  , 0.16076336, 0.10977726, 0.08063812,
#          0.07475586]),
#   'std_fit_time': array([0.00744389, 0.03876207, 0.0522774 , 0.00938106, 0.00333236,
#          0.00639729]),
#   'mean_score_time': array([0.0163492 , 0.03134265, 0.01642833, 0.01699014, 0.01684494,
#          0.01635427]),
#   'std_score_time': array([0.00148897, 0.00608267, 0.00048159, 0.00138535, 0.00105957,
#          0.00066323]),
#   'param_logisticregression__C': masked_array(data=[100, 10, 1, 0.1, 0.01, 0.001],
#                mask=[False, False, False, False, False, False],
#          fill_value='?',
#               dtype=object),
#   'params': [{'logisticregression__C': 100},
#    {'logisticregression__C': 10},
#    {'logisticregression__C': 1},
#    {'logisticregression__C': 0.1},
#    {'logisticregression__C': 0.01},
#    {'logisticregression__C': 0.001}],
#   'split0_test_score': array([0.85065932, 0.85052986, 0.85003052, 0.84808862, 0.84193005,
#          0.83549407]),
#   'split1_test_score': array([0.87129885, 0.87120638, 0.87103993, 0.87052209, 0.86895008,
#          0.86375321]),
#   'split2_test_score': array([0.84686801, 0.84681252, 0.84640565, 0.8446672 , 0.83719554,
#          0.82665384]),
#   'split3_test_score': array([0.82554674, 0.82550948, 0.82547223, 0.8260497 , 0.82889982,
#          0.82837823]),
#   'split4_test_score': array([0.8477702 , 0.84754666, 0.84674565, 0.84627994, 0.84635446,
#          0.85013599]),
#   'split5_test_score': array([0.82198875, 0.82219366, 0.82217503, 0.8225476 , 0.81990239,
#          0.81440706]),
#   'split6_test_score': array([0.84745352, 0.84734175, 0.8470437 , 0.84652211, 0.8469133 ,
#          0.84668977]),
#   'split7_test_score': array([0.86373459, 0.86410715, 0.86451697, 0.8659886 , 0.86326888,
#          0.85546366]),
#   'split8_test_score': array([0.83996498, 0.84015126, 0.83966693, 0.83962967, 0.83894043,
#          0.83771096]),
#   'split9_test_score': array([0.83074983, 0.83084254, 0.83056441, 0.82863606, 0.82144182,
#          0.81613884]),
#   'mean_test_score': array([0.84460348, 0.84462413, 0.8443661 , 0.84389316, 0.84137968,
#          0.83748256]),
#   'std_test_score': array([0.01492186, 0.01490044, 0.01492856, 0.01501032, 0.01527394,
#          0.01565419]),
#   'rank_test_score': array([2, 1, 3, 4, 5, 6], dtype=int32)},
#  'n_splits_': 10}

# %% [markdown]
# Выпишите какое лучшее качество и с какими параметрами вам удалось получить

# %% [markdown]
# ## Применение градиентного бустинга (2 балла)
#
# Если вы хотите получить баллы за точный ответ, то стоит попробовать градиентный бустинг. Часто градиентный бустинг с параметрами по умолчанию даст вам 80% результата за 0% усилий.
#
# Мы будем использовать catboost, поэтому нам не надо кодировать категориальные признаки. Catboost сделает это сам (в .fit() надо передать cat_features=cat_cols). А численные признаки нормировать для моделей, основанных на деревьях не нужно.
#
# 1) Разделите выборку на train/valid. Протестируйте catboost cо стандартными параметрами.
#
# 2) Протестируйте разные занчения параметроа количества деревьев и learning_rate'а и выберите лучшую по метрике ROC-AUC комбинацию.
#
# (Дополнительно) Есть некоторые сложности с тем, чтобы использовать CatBoostClassifier вместе с GridSearchCV, поэтому мы не просим использовать кроссвалидацию. Но можете попробовать)

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)

# %%
import catboost # документация: https://catboost.ai/docs

X_train_origin, X_test_origin, y_train, y_test = train_test_split(
    data.drop(target_col, axis=1), data[target_col],
    train_size=0.8,
    random_state=42)

# %%
boosting_model = catboost.CatBoostClassifier(n_estimators=200,
                                             cat_features=cat_cols)

boosting_model.fit(X_train_origin, y_train)

y_train_predicted = boosting_model.predict_proba(X_train_origin)[:, 1]
y_test_predicted = boosting_model.predict_proba(X_test_origin)[:, 1]
# Out:
# Learning rate set to 0.083332
# 0:	learn: 0.6393850	total: 16.6ms	remaining: 3.3s
# 1:	learn: 0.5986678	total: 31ms	remaining: 3.07s
# 2:	learn: 0.5669397	total: 41.8ms	remaining: 2.75s
# 3:	learn: 0.5401092	total: 55.7ms	remaining: 2.73s
# 4:	learn: 0.5184259	total: 70ms	remaining: 2.73s
# 5:	learn: 0.5006508	total: 83.7ms	remaining: 2.71s
# 6:	learn: 0.4860068	total: 98.3ms	remaining: 2.71s
# 7:	learn: 0.4729220	total: 129ms	remaining: 3.11s
# 8:	learn: 0.4613053	total: 161ms	remaining: 3.42s
# 9:	learn: 0.4518849	total: 201ms	remaining: 3.83s
# 10:	learn: 0.4444709	total: 234ms	remaining: 4.02s
# 11:	learn: 0.4389258	total: 270ms	remaining: 4.22s
# 12:	learn: 0.4351742	total: 294ms	remaining: 4.23s
# 13:	learn: 0.4308061	total: 328ms	remaining: 4.36s
# 14:	learn: 0.4263292	total: 361ms	remaining: 4.46s
# 15:	learn: 0.4224699	total: 399ms	remaining: 4.58s
# 16:	learn: 0.4199115	total: 432ms	remaining: 4.64s
# 17:	learn: 0.4175362	total: 455ms	remaining: 4.6s
# 18:	learn: 0.4142761	total: 486ms	remaining: 4.63s
# 19:	learn: 0.4125824	total: 520ms	remaining: 4.68s
# 20:	learn: 0.4106805	total: 547ms	remaining: 4.66s
# 21:	learn: 0.4100943	total: 560ms	remaining: 4.53s
# 22:	learn: 0.4086343	total: 588ms	remaining: 4.53s
# 23:	learn: 0.4068653	total: 617ms	remaining: 4.53s
# 24:	learn: 0.4053385	total: 643ms	remaining: 4.5s
# 25:	learn: 0.4040037	total: 671ms	remaining: 4.49s
# 26:	learn: 0.4032561	total: 696ms	remaining: 4.46s
# 27:	learn: 0.4024138	total: 718ms	remaining: 4.41s
# 28:	learn: 0.4008988	total: 743ms	remaining: 4.38s
# 29:	learn: 0.4001330	total: 772ms	remaining: 4.38s
# 30:	learn: 0.3998920	total: 790ms	remaining: 4.31s
# 31:	learn: 0.3986352	total: 822ms	remaining: 4.31s
# 32:	learn: 0.3984955	total: 835ms	remaining: 4.23s
# 33:	learn: 0.3974771	total: 862ms	remaining: 4.21s
# 34:	learn: 0.3966830	total: 888ms	remaining: 4.19s
# 35:	learn: 0.3964145	total: 901ms	remaining: 4.1s
# 36:	learn: 0.3958449	total: 931ms	remaining: 4.1s
# 37:	learn: 0.3951034	total: 962ms	remaining: 4.1s
# 38:	learn: 0.3940753	total: 992ms	remaining: 4.1s
# 39:	learn: 0.3939314	total: 1.01s	remaining: 4.03s
# 40:	learn: 0.3933080	total: 1.03s	remaining: 4.01s
# 41:	learn: 0.3925020	total: 1.07s	remaining: 4.01s
# 42:	learn: 0.3925013	total: 1.07s	remaining: 3.92s
# 43:	learn: 0.3922959	total: 1.1s	remaining: 3.91s
# 44:	learn: 0.3916142	total: 1.13s	remaining: 3.9s
# 45:	learn: 0.3908284	total: 1.16s	remaining: 3.89s
# 46:	learn: 0.3904076	total: 1.19s	remaining: 3.87s
# 47:	learn: 0.3894747	total: 1.22s	remaining: 3.87s
# 48:	learn: 0.3890743	total: 1.25s	remaining: 3.85s
# 49:	learn: 0.3885796	total: 1.28s	remaining: 3.85s
# 50:	learn: 0.3885796	total: 1.29s	remaining: 3.77s
# 51:	learn: 0.3877753	total: 1.31s	remaining: 3.73s
# 52:	learn: 0.3875378	total: 1.35s	remaining: 3.75s
# 53:	learn: 0.3867899	total: 1.38s	remaining: 3.73s
# 54:	learn: 0.3862942	total: 1.41s	remaining: 3.72s
# 55:	learn: 0.3862692	total: 1.42s	remaining: 3.65s
# 56:	learn: 0.3860733	total: 1.44s	remaining: 3.6s
# 57:	learn: 0.3859114	total: 1.47s	remaining: 3.6s
# 58:	learn: 0.3858461	total: 1.49s	remaining: 3.55s
# 59:	learn: 0.3855916	total: 1.51s	remaining: 3.52s
# 60:	learn: 0.3848055	total: 1.53s	remaining: 3.5s
# 61:	learn: 0.3840814	total: 1.56s	remaining: 3.48s
# 62:	learn: 0.3840254	total: 1.58s	remaining: 3.45s
# 63:	learn: 0.3839906	total: 1.6s	remaining: 3.39s
# 64:	learn: 0.3837327	total: 1.63s	remaining: 3.39s
# 65:	learn: 0.3833261	total: 1.66s	remaining: 3.37s
# 66:	learn: 0.3825917	total: 1.69s	remaining: 3.35s
# 67:	learn: 0.3823562	total: 1.72s	remaining: 3.33s
# 68:	learn: 0.3817686	total: 1.75s	remaining: 3.31s
# 69:	learn: 0.3816211	total: 1.77s	remaining: 3.28s
# 70:	learn: 0.3813737	total: 1.79s	remaining: 3.26s
# 71:	learn: 0.3813502	total: 1.8s	remaining: 3.21s
# 72:	learn: 0.3808819	total: 1.83s	remaining: 3.18s
# 73:	learn: 0.3798934	total: 1.86s	remaining: 3.17s
# 74:	learn: 0.3794574	total: 1.89s	remaining: 3.15s
# 75:	learn: 0.3793537	total: 1.9s	remaining: 3.11s
# 76:	learn: 0.3788948	total: 1.93s	remaining: 3.08s
# 77:	learn: 0.3783271	total: 1.96s	remaining: 3.07s
# 78:	learn: 0.3780525	total: 1.99s	remaining: 3.05s
# 79:	learn: 0.3779892	total: 2.01s	remaining: 3.02s
# 80:	learn: 0.3772354	total: 2.04s	remaining: 3s
# 81:	learn: 0.3766600	total: 2.07s	remaining: 2.98s
# 82:	learn: 0.3761457	total: 2.1s	remaining: 2.96s
# 83:	learn: 0.3761402	total: 2.11s	remaining: 2.92s
# 84:	learn: 0.3761153	total: 2.14s	remaining: 2.89s
# 85:	learn: 0.3757109	total: 2.17s	remaining: 2.88s
# 86:	learn: 0.3755057	total: 2.2s	remaining: 2.86s
# 87:	learn: 0.3752161	total: 2.23s	remaining: 2.84s
# 88:	learn: 0.3749418	total: 2.26s	remaining: 2.82s
# 89:	learn: 0.3743063	total: 2.29s	remaining: 2.8s
# 90:	learn: 0.3741375	total: 2.33s	remaining: 2.79s
# 91:	learn: 0.3735867	total: 2.36s	remaining: 2.77s
# 92:	learn: 0.3728390	total: 2.39s	remaining: 2.75s
# 93:	learn: 0.3726758	total: 2.41s	remaining: 2.72s
# 94:	learn: 0.3718457	total: 2.45s	remaining: 2.7s
# 95:	learn: 0.3714807	total: 2.48s	remaining: 2.69s
# 96:	learn: 0.3712320	total: 2.51s	remaining: 2.66s
# 97:	learn: 0.3711793	total: 2.54s	remaining: 2.65s
# 98:	learn: 0.3708805	total: 2.58s	remaining: 2.64s
# 99:	learn: 0.3705140	total: 2.62s	remaining: 2.62s
# 100:	learn: 0.3702073	total: 2.65s	remaining: 2.6s
# 101:	learn: 0.3696133	total: 2.67s	remaining: 2.57s
# 102:	learn: 0.3687721	total: 2.69s	remaining: 2.53s
# 103:	learn: 0.3684416	total: 2.7s	remaining: 2.49s
# 104:	learn: 0.3681062	total: 2.72s	remaining: 2.46s
# 105:	learn: 0.3676945	total: 2.73s	remaining: 2.42s
# 106:	learn: 0.3674837	total: 2.75s	remaining: 2.39s
# 107:	learn: 0.3670150	total: 2.76s	remaining: 2.35s
# 108:	learn: 0.3666500	total: 2.78s	remaining: 2.32s
# 109:	learn: 0.3658847	total: 2.8s	remaining: 2.29s
# 110:	learn: 0.3651169	total: 2.82s	remaining: 2.26s
# 111:	learn: 0.3642514	total: 2.83s	remaining: 2.22s
# 112:	learn: 0.3636622	total: 2.85s	remaining: 2.19s
# 113:	learn: 0.3633506	total: 2.86s	remaining: 2.16s
# 114:	learn: 0.3627703	total: 2.87s	remaining: 2.12s
# 115:	learn: 0.3618978	total: 2.89s	remaining: 2.09s
# 116:	learn: 0.3615906	total: 2.9s	remaining: 2.06s
# 117:	learn: 0.3610257	total: 2.92s	remaining: 2.03s
# 118:	learn: 0.3604401	total: 2.93s	remaining: 2s
# 119:	learn: 0.3594542	total: 2.95s	remaining: 1.97s
# 120:	learn: 0.3588681	total: 2.97s	remaining: 1.94s
# 121:	learn: 0.3586290	total: 2.98s	remaining: 1.91s
# 122:	learn: 0.3583895	total: 3s	remaining: 1.88s
# 123:	learn: 0.3579040	total: 3.01s	remaining: 1.85s
# 124:	learn: 0.3576181	total: 3.03s	remaining: 1.82s
# 125:	learn: 0.3571910	total: 3.04s	remaining: 1.79s
# 126:	learn: 0.3566694	total: 3.06s	remaining: 1.76s
# 127:	learn: 0.3563513	total: 3.07s	remaining: 1.73s
# 128:	learn: 0.3558232	total: 3.09s	remaining: 1.7s
# 129:	learn: 0.3552659	total: 3.1s	remaining: 1.67s
# 130:	learn: 0.3541500	total: 3.12s	remaining: 1.64s
# 131:	learn: 0.3535561	total: 3.13s	remaining: 1.61s
# 132:	learn: 0.3532243	total: 3.15s	remaining: 1.59s
# 133:	learn: 0.3526529	total: 3.17s	remaining: 1.56s
# 134:	learn: 0.3521707	total: 3.19s	remaining: 1.53s
# 135:	learn: 0.3515384	total: 3.2s	remaining: 1.51s
# 136:	learn: 0.3509887	total: 3.22s	remaining: 1.48s
# 137:	learn: 0.3504353	total: 3.23s	remaining: 1.45s
# 138:	learn: 0.3501934	total: 3.25s	remaining: 1.42s
# 139:	learn: 0.3497991	total: 3.26s	remaining: 1.4s
# 140:	learn: 0.3496516	total: 3.27s	remaining: 1.37s
# 141:	learn: 0.3491151	total: 3.29s	remaining: 1.34s
# 142:	learn: 0.3487621	total: 3.3s	remaining: 1.32s
# 143:	learn: 0.3486158	total: 3.32s	remaining: 1.29s
# 144:	learn: 0.3482835	total: 3.33s	remaining: 1.26s
# 145:	learn: 0.3479918	total: 3.35s	remaining: 1.24s
# 146:	learn: 0.3478319	total: 3.36s	remaining: 1.21s
# 147:	learn: 0.3477123	total: 3.38s	remaining: 1.19s
# 148:	learn: 0.3472270	total: 3.39s	remaining: 1.16s
# 149:	learn: 0.3470823	total: 3.41s	remaining: 1.14s
# 150:	learn: 0.3466258	total: 3.43s	remaining: 1.11s
# 151:	learn: 0.3464967	total: 3.44s	remaining: 1.09s
# 152:	learn: 0.3459971	total: 3.46s	remaining: 1.06s
# 153:	learn: 0.3458168	total: 3.47s	remaining: 1.04s
# 154:	learn: 0.3454995	total: 3.48s	remaining: 1.01s
# 155:	learn: 0.3452478	total: 3.5s	remaining: 989ms
# 156:	learn: 0.3451798	total: 3.52s	remaining: 964ms
# 157:	learn: 0.3448005	total: 3.53s	remaining: 939ms
# 158:	learn: 0.3440715	total: 3.55s	remaining: 915ms
# 159:	learn: 0.3436916	total: 3.57s	remaining: 893ms
# 160:	learn: 0.3434870	total: 3.58s	remaining: 869ms
# 161:	learn: 0.3432215	total: 3.6s	remaining: 844ms
# 162:	learn: 0.3430880	total: 3.61s	remaining: 820ms
# 163:	learn: 0.3427581	total: 3.63s	remaining: 796ms
# 164:	learn: 0.3424597	total: 3.64s	remaining: 773ms
# 165:	learn: 0.3423600	total: 3.66s	remaining: 749ms
# 166:	learn: 0.3420330	total: 3.67s	remaining: 725ms
# 167:	learn: 0.3416798	total: 3.68s	remaining: 701ms
# 168:	learn: 0.3412737	total: 3.7s	remaining: 678ms
# 169:	learn: 0.3404688	total: 3.72s	remaining: 656ms
# 170:	learn: 0.3399286	total: 3.75s	remaining: 636ms
# 171:	learn: 0.3395102	total: 3.76s	remaining: 613ms
# 172:	learn: 0.3392105	total: 3.78s	remaining: 591ms
# 173:	learn: 0.3389528	total: 3.8s	remaining: 568ms
# 174:	learn: 0.3385231	total: 3.83s	remaining: 546ms
# 175:	learn: 0.3382915	total: 3.84s	remaining: 524ms
# 176:	learn: 0.3374019	total: 3.85s	remaining: 501ms
# 177:	learn: 0.3369077	total: 3.87s	remaining: 478ms
# 178:	learn: 0.3366573	total: 3.88s	remaining: 456ms
# 179:	learn: 0.3364366	total: 3.9s	remaining: 433ms
# 180:	learn: 0.3360432	total: 3.92s	remaining: 411ms
# 181:	learn: 0.3355215	total: 3.93s	remaining: 389ms
# 182:	learn: 0.3353405	total: 3.94s	remaining: 366ms
# 183:	learn: 0.3347534	total: 3.96s	remaining: 344ms
# 184:	learn: 0.3344863	total: 3.97s	remaining: 322ms
# 185:	learn: 0.3343503	total: 3.99s	remaining: 301ms
# 186:	learn: 0.3338920	total: 4.01s	remaining: 279ms
# 187:	learn: 0.3334944	total: 4.03s	remaining: 257ms
# 188:	learn: 0.3327864	total: 4.04s	remaining: 235ms
# 189:	learn: 0.3327116	total: 4.05s	remaining: 213ms
# 190:	learn: 0.3325706	total: 4.07s	remaining: 192ms
# 191:	learn: 0.3324350	total: 4.08s	remaining: 170ms
# 192:	learn: 0.3321759	total: 4.1s	remaining: 149ms
# 193:	learn: 0.3319562	total: 4.11s	remaining: 127ms
# 194:	learn: 0.3316261	total: 4.13s	remaining: 106ms
# 195:	learn: 0.3314515	total: 4.15s	remaining: 84.6ms
# 196:	learn: 0.3307845	total: 4.16s	remaining: 63.4ms
# 197:	learn: 0.3304574	total: 4.18s	remaining: 42.2ms
# 198:	learn: 0.3297162	total: 4.19s	remaining: 21.1ms
# 199:	learn: 0.3294067	total: 4.21s	remaining: 0us

# %%
from sklearn.metrics import roc_auc_score, roc_curve

train_auc = roc_auc_score(y_train, y_train_predicted)
test_auc = roc_auc_score(y_test, y_test_predicted)

plt.figure(figsize=(10,7))
plt.plot(*roc_curve(y_train, y_train_predicted)[:2], label='train AUC={:.4f}'.format(train_auc))
plt.plot(*roc_curve(y_test, y_test_predicted)[:2], label='test AUC={:.4f}'.format(test_auc))
legend_box = plt.legend(fontsize='large', framealpha=1).get_frame()
legend_box.set_facecolor("white")
legend_box.set_edgecolor("black")
plt.plot(np.linspace(0,1,100), np.linspace(0,1,100))
plt.show()

# %%
model = catboost.CatBoostClassifier(
    cat_features=cat_cols)

parameters = {'depth'         : [6, 7, 8,],
              'learning_rate' : [0.79, 0.0805, 0.081],
              'iterations'    : [75, 80],
              'random_state'  : [42],
              }

result = GridSearchCV(
    estimator=model,
    param_grid = parameters,
    cv = 2,
    n_jobs=-1)
result.fit(X_train_origin, y_train)

print("Results from Grid Search")
print("\n The best estimator across ALL searched params:\n",result.best_estimator_)
print("\n The best score across ALL searched params:\n",result.best_score_)
print("\n The best parameters across ALL searched params:\n",result.best_params_)
# Out:
# 0:	learn: 0.6645450	total: 7.06ms	remaining: 558ms
# 1:	learn: 0.6398317	total: 13.2ms	remaining: 516ms
# 2:	learn: 0.6185605	total: 18.3ms	remaining: 468ms
# 3:	learn: 0.5987796	total: 22.9ms	remaining: 436ms
# 4:	learn: 0.5813603	total: 27.6ms	remaining: 413ms
# 5:	learn: 0.5658569	total: 33.3ms	remaining: 411ms
# 6:	learn: 0.5522470	total: 38.2ms	remaining: 399ms
# 7:	learn: 0.5399206	total: 43.1ms	remaining: 388ms
# 8:	learn: 0.5289058	total: 47.9ms	remaining: 378ms
# 9:	learn: 0.5194347	total: 52.6ms	remaining: 368ms
# 10:	learn: 0.5113992	total: 57.7ms	remaining: 362ms
# 11:	learn: 0.5031453	total: 60.1ms	remaining: 340ms
# 12:	learn: 0.4948542	total: 64.7ms	remaining: 334ms
# 13:	learn: 0.4877536	total: 68.3ms	remaining: 322ms
# 14:	learn: 0.4813591	total: 71.3ms	remaining: 309ms
# 15:	learn: 0.4750305	total: 76.1ms	remaining: 305ms
# 16:	learn: 0.4698126	total: 80.7ms	remaining: 299ms
# 17:	learn: 0.4652516	total: 85.3ms	remaining: 294ms
# 18:	learn: 0.4607786	total: 89.2ms	remaining: 286ms
# 19:	learn: 0.4574247	total: 93.8ms	remaining: 281ms
# 20:	learn: 0.4538098	total: 98.3ms	remaining: 276ms
# 21:	learn: 0.4505829	total: 103ms	remaining: 272ms
# 22:	learn: 0.4475003	total: 108ms	remaining: 267ms
# 23:	learn: 0.4447566	total: 112ms	remaining: 262ms
# 24:	learn: 0.4414178	total: 117ms	remaining: 258ms
# 25:	learn: 0.4387325	total: 120ms	remaining: 249ms
# 26:	learn: 0.4362516	total: 125ms	remaining: 246ms
# 27:	learn: 0.4333868	total: 130ms	remaining: 241ms
# 28:	learn: 0.4307479	total: 135ms	remaining: 237ms
# 29:	learn: 0.4288761	total: 138ms	remaining: 230ms
# 30:	learn: 0.4272631	total: 140ms	remaining: 221ms
# 31:	learn: 0.4254426	total: 144ms	remaining: 215ms
# 32:	learn: 0.4235505	total: 148ms	remaining: 211ms
# 33:	learn: 0.4214629	total: 153ms	remaining: 207ms
# 34:	learn: 0.4198996	total: 157ms	remaining: 202ms
# 35:	learn: 0.4187871	total: 159ms	remaining: 195ms
# 36:	learn: 0.4179722	total: 162ms	remaining: 188ms
# 37:	learn: 0.4164405	total: 166ms	remaining: 184ms
# 38:	learn: 0.4155507	total: 171ms	remaining: 180ms
# 39:	learn: 0.4146039	total: 175ms	remaining: 175ms
# 40:	learn: 0.4138467	total: 178ms	remaining: 169ms
# 41:	learn: 0.4123985	total: 182ms	remaining: 165ms
# 42:	learn: 0.4117432	total: 185ms	remaining: 159ms
# 43:	learn: 0.4114044	total: 187ms	remaining: 153ms
# 44:	learn: 0.4102472	total: 193ms	remaining: 150ms
# 45:	learn: 0.4089902	total: 197ms	remaining: 146ms
# 46:	learn: 0.4080137	total: 206ms	remaining: 145ms
# 47:	learn: 0.4071738	total: 211ms	remaining: 141ms
# 48:	learn: 0.4066344	total: 216ms	remaining: 137ms
# 49:	learn: 0.4058809	total: 221ms	remaining: 132ms
# 50:	learn: 0.4051398	total: 225ms	remaining: 128ms
# 51:	learn: 0.4044983	total: 230ms	remaining: 124ms
# 52:	learn: 0.4039675	total: 236ms	remaining: 120ms
# 53:	learn: 0.4036082	total: 241ms	remaining: 116ms
# 54:	learn: 0.4031359	total: 246ms	remaining: 112ms
# 55:	learn: 0.4022265	total: 250ms	remaining: 107ms
# 56:	learn: 0.4019112	total: 254ms	remaining: 103ms
# 57:	learn: 0.4016288	total: 259ms	remaining: 98.3ms
# 58:	learn: 0.4010799	total: 264ms	remaining: 93.9ms
# 59:	learn: 0.4008462	total: 267ms	remaining: 88.9ms
# 60:	learn: 0.4007456	total: 269ms	remaining: 83.9ms
# 61:	learn: 0.4005508	total: 274ms	remaining: 79.5ms
# 62:	learn: 0.3997554	total: 278ms	remaining: 75.1ms
# 63:	learn: 0.3993134	total: 283ms	remaining: 70.7ms
# 64:	learn: 0.3989142	total: 288ms	remaining: 66.4ms
# 65:	learn: 0.3981256	total: 292ms	remaining: 62ms
# 66:	learn: 0.3978448	total: 297ms	remaining: 57.7ms
# 67:	learn: 0.3977627	total: 303ms	remaining: 53.5ms
# 68:	learn: 0.3976772	total: 309ms	remaining: 49.3ms
# 69:	learn: 0.3973496	total: 319ms	remaining: 45.6ms
# 70:	learn: 0.3972009	total: 321ms	remaining: 40.7ms
# 71:	learn: 0.3971959	total: 323ms	remaining: 35.8ms
# 72:	learn: 0.3971950	total: 324ms	remaining: 31.1ms
# 73:	learn: 0.3971393	total: 326ms	remaining: 26.4ms
# 74:	learn: 0.3966605	total: 330ms	remaining: 22ms
# 75:	learn: 0.3962337	total: 335ms	remaining: 17.6ms
# 76:	learn: 0.3959124	total: 340ms	remaining: 13.2ms
# 77:	learn: 0.3958224	total: 345ms	remaining: 8.83ms
# 78:	learn: 0.3954530	total: 349ms	remaining: 4.42ms
# 79:	learn: 0.3951443	total: 354ms	remaining: 0us
# Results from Grid Search
#
#  The best estimator across ALL searched params:
#  <catboost.core.CatBoostClassifier object at 0x7b626668a440>
#
#  The best score across ALL searched params:
#  0.8036984352773826
#
#  The best parameters across ALL searched params:
#  {'depth': 6, 'iterations': 80, 'learning_rate': 0.081, 'random_state': 42}

# %%
best_model = result.best_estimator_
y_train_predicted = best_model.predict_proba(X_train_origin)[:, 1]
y_test_predicted = best_model.predict_proba(X_test_origin)[:, 1]

# %%
from sklearn.metrics import roc_auc_score, roc_curve

train_auc = roc_auc_score(y_train, y_train_predicted)
test_auc = roc_auc_score(y_test, y_test_predicted)

plt.figure(figsize=(10,7))
plt.plot(*roc_curve(y_train, y_train_predicted)[:2], label='train AUC={:.4f}'.format(train_auc))
plt.plot(*roc_curve(y_test, y_test_predicted)[:2], label='test AUC={:.4f}'.format(test_auc))
legend_box = plt.legend(fontsize='large', framealpha=1).get_frame()
legend_box.set_facecolor("white")
legend_box.set_edgecolor("black")
plt.plot(np.linspace(0,1,100), np.linspace(0,1,100))
plt.show()

# %%
#Лайфхак переучиваемся на полном наборе данных
best_model = catboost.CatBoostClassifier(
    cat_features=cat_cols,
    depth=result.best_params_["depth"],
    learning_rate=result.best_params_["learning_rate"],
    iterations=result.best_params_["iterations"])

best_model.fit(data.drop(target_col, axis=1), data[target_col])
# Out:
# 0:	learn: 0.6640789	total: 7.61ms	remaining: 602ms
# 1:	learn: 0.6382373	total: 15.1ms	remaining: 587ms
# 2:	learn: 0.6161462	total: 22.3ms	remaining: 573ms
# 3:	learn: 0.5956375	total: 29.2ms	remaining: 555ms
# 4:	learn: 0.5778792	total: 35.7ms	remaining: 536ms
# 5:	learn: 0.5625387	total: 42.1ms	remaining: 520ms
# 6:	learn: 0.5487561	total: 48.5ms	remaining: 506ms
# 7:	learn: 0.5371121	total: 55.3ms	remaining: 498ms
# 8:	learn: 0.5267502	total: 62ms	remaining: 489ms
# 9:	learn: 0.5170241	total: 68.9ms	remaining: 482ms
# 10:	learn: 0.5082520	total: 75.7ms	remaining: 475ms
# 11:	learn: 0.5003101	total: 82.5ms	remaining: 468ms
# 12:	learn: 0.4931346	total: 89.6ms	remaining: 462ms
# 13:	learn: 0.4865021	total: 96.3ms	remaining: 454ms
# 14:	learn: 0.4810314	total: 103ms	remaining: 446ms
# 15:	learn: 0.4760925	total: 110ms	remaining: 438ms
# 16:	learn: 0.4710792	total: 116ms	remaining: 431ms
# 17:	learn: 0.4661493	total: 121ms	remaining: 418ms
# 18:	learn: 0.4610857	total: 128ms	remaining: 411ms
# 19:	learn: 0.4569966	total: 130ms	remaining: 391ms
# 20:	learn: 0.4528951	total: 137ms	remaining: 384ms
# 21:	learn: 0.4494034	total: 143ms	remaining: 378ms
# 22:	learn: 0.4465697	total: 145ms	remaining: 360ms
# 23:	learn: 0.4435095	total: 152ms	remaining: 354ms
# 24:	learn: 0.4412777	total: 154ms	remaining: 339ms
# 25:	learn: 0.4381347	total: 161ms	remaining: 334ms
# 26:	learn: 0.4355778	total: 164ms	remaining: 322ms
# 27:	learn: 0.4326452	total: 171ms	remaining: 318ms
# 28:	learn: 0.4304078	total: 178ms	remaining: 313ms
# 29:	learn: 0.4282795	total: 183ms	remaining: 305ms
# 30:	learn: 0.4261101	total: 190ms	remaining: 300ms
# 31:	learn: 0.4238583	total: 196ms	remaining: 295ms
# 32:	learn: 0.4221989	total: 199ms	remaining: 284ms
# 33:	learn: 0.4206048	total: 210ms	remaining: 285ms
# 34:	learn: 0.4195159	total: 213ms	remaining: 274ms
# 35:	learn: 0.4178228	total: 220ms	remaining: 269ms
# 36:	learn: 0.4161488	total: 227ms	remaining: 264ms
# 37:	learn: 0.4144850	total: 234ms	remaining: 259ms
# 38:	learn: 0.4130245	total: 241ms	remaining: 253ms
# 39:	learn: 0.4115981	total: 247ms	remaining: 247ms
# 40:	learn: 0.4101828	total: 254ms	remaining: 242ms
# 41:	learn: 0.4088073	total: 261ms	remaining: 236ms
# 42:	learn: 0.4080636	total: 267ms	remaining: 230ms
# 43:	learn: 0.4070664	total: 274ms	remaining: 225ms
# 44:	learn: 0.4061815	total: 282ms	remaining: 219ms
# 45:	learn: 0.4053986	total: 288ms	remaining: 213ms
# 46:	learn: 0.4047345	total: 295ms	remaining: 207ms
# 47:	learn: 0.4036331	total: 301ms	remaining: 201ms
# 48:	learn: 0.4029487	total: 308ms	remaining: 195ms
# 49:	learn: 0.4027793	total: 310ms	remaining: 186ms
# 50:	learn: 0.4023455	total: 316ms	remaining: 180ms
# 51:	learn: 0.4016947	total: 323ms	remaining: 174ms
# 52:	learn: 0.4015397	total: 326ms	remaining: 166ms
# 53:	learn: 0.4009247	total: 333ms	remaining: 160ms
# 54:	learn: 0.4004935	total: 342ms	remaining: 155ms
# 55:	learn: 0.3996871	total: 349ms	remaining: 150ms
# 56:	learn: 0.3995861	total: 351ms	remaining: 142ms
# 57:	learn: 0.3990131	total: 356ms	remaining: 135ms
# 58:	learn: 0.3983173	total: 363ms	remaining: 129ms
# 59:	learn: 0.3977886	total: 370ms	remaining: 123ms
# 60:	learn: 0.3974109	total: 378ms	remaining: 118ms
# 61:	learn: 0.3969910	total: 384ms	remaining: 112ms
# 62:	learn: 0.3964782	total: 391ms	remaining: 105ms
# 63:	learn: 0.3958811	total: 397ms	remaining: 99.3ms
# 64:	learn: 0.3958350	total: 400ms	remaining: 92.3ms
# 65:	learn: 0.3957181	total: 405ms	remaining: 85.9ms
# 66:	learn: 0.3949092	total: 414ms	remaining: 80.3ms
# 67:	learn: 0.3947440	total: 419ms	remaining: 74ms
# 68:	learn: 0.3939075	total: 431ms	remaining: 68.7ms
# 69:	learn: 0.3938312	total: 436ms	remaining: 62.3ms
# 70:	learn: 0.3936335	total: 443ms	remaining: 56.1ms
# 71:	learn: 0.3935620	total: 446ms	remaining: 49.5ms
# 72:	learn: 0.3930915	total: 453ms	remaining: 43.4ms
# 73:	learn: 0.3928413	total: 460ms	remaining: 37.3ms
# 74:	learn: 0.3928381	total: 462ms	remaining: 30.8ms
# 75:	learn: 0.3928354	total: 464ms	remaining: 24.4ms
# 76:	learn: 0.3927186	total: 468ms	remaining: 18.2ms
# 77:	learn: 0.3926782	total: 475ms	remaining: 12.2ms
# 78:	learn: 0.3922222	total: 482ms	remaining: 6.1ms
# 79:	learn: 0.3920741	total: 488ms	remaining: 0us

# %% [markdown]
# Выпишите, какое лучшее качество и с какими параметрами вам удалось получить

# %% [markdown]
# ВАШ ОТВЕТ

# %% [markdown]
# # Предсказания

# %%
X_test = pd.read_csv('./test.csv')
submission = pd.read_csv('./submission.csv')
submission['Churn'] = best_model.predict_proba(X_test)[:,1]
submission.head
submission.to_csv('./my_submission.csv', index=False)

# %% [markdown]
# Лучшее решение отправьте в Stepik.
