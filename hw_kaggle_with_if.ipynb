# %% [markdown]
# <a href="https://colab.research.google.com/github/apodvoisky/DLS2023/blob/hw-07/hw_kaggle_with_if.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание. Решение конкурса на kaggle.com
#
# Это домашнее задание посвящено полноценному решению задачи машинного обучения.

# %% [markdown]
# Есть две части этого домашнего задания:
#
# ### Отправить ваши предсказания в Stepik.
# За прохождение определенных порогов будут начисляться баллы. Эта часть оценивается из 5 баллов.
#
# 1) $1.00 \geqslant score \geqslant 0.84$ --- 5 баллов
#
# 2) $0.84 > score \geqslant 0.77$ --- 4 балла
#
# 3) $0.77 > score \geqslant 0.70$ --- 3 балла
#
# 4) $0.70 > score \geqslant 0.65$ --- 2 балла
#
# 5) $0.65 > score \geqslant 0.6$ --- 1 балл
#
# 6) $0.60 > score$ --- 0 баллов
#
# Для этого мы предварительно разделили данные в задании на две части.
# * `train.csv`. На этом наборе данных вам необходимо создать и обучить модель. Подробное описание файла есть в ноутбуке.
# * `test.csv`. В каждой строчке файла `test.csv` указаны признаки тестовых объектов. Предсказания для этого набора необходимо записать в файл submission.csv и сдать в соответствующий шаг на Stepik. Количество попыток ограничено 100 штук.
#
# Отправлять в Stepik вы будете файл с ответами `my_submission.csv`. В этом файле вам необходимо для каждого объекта из датасета предсказать вероятность класса 1. Мы подготовили для вас файл с примером посылки `submission.csv`. Ваш файл должен быть оформлен таким же образом. В ноутбуке есть пример оформления файла посылки. Для отправки файла с предсказаниями на Stepik есть отдельный шаг.
#
# ### Сделать полноценный отчет о вашей работе.
# Опишите, как вы обработали данные, какие модели попробовали и какие результаты получились (максимум 10 баллов). За каждую выполненную часть будет начислено определенное количество баллов. В этом пункте вам необходимо отправить файл в формате .ipynb на Stepik --- для этого в домашнем задании есть отдельный шаг. Этот пункт оценивается из 10 баллов.
#
# **Вторая часть будет проверяться в формате peer-review. Т.е. вашу посылку на Stepik будут проверять 3 других студента, и медианное значение их оценок будет выставлено. Чтобы получить баллы, вам также нужно будет проверить трех других учеников. Это станет доступно после того, как вы сдадите задание сами.**
#
# ### Контест на Kaggle
# Для вашего удобства мы подготовили [контест на Kaggle](https://www.kaggle.com/c/advanced-dls-spring-2021/). Тестирующая система на Kaggle выдает те же баллы, что и Stepik. Мы рекомендуем в качестве основной тестирующей системы использовать именно Kaggle, а затем сдать лучшую посылку на Stepik. Так вы привыкните работать с Kaggle.
#
# Проблема для российских пользователей Kaggle заключается в том, что подтверждение аккаунта по номеру телефона работает с перебоями или не работает вообще. Без подтвержденного номера телефона вы не сможете совершать посылки в kaggle. Если у вас возникла такая проблема, мы советуем следующие шаги:
# * Попробовать зарегистрировать аккаунт с аутентификацией через gmail. В таком случае, аккаунт должен работать без подтверждения номера телефона.
# * Если у вас есть не российский номер, используйте его для верификации аккаунта.
# * Если на номер телефона не приходит смс для верификации аккаунта, обратитесь в службу поддержки kaggle. Они с переменным успехом умеют подтверждать аккаунты вручную.
# * Если все же подтвердить аккаунт и получить доступ к сдаче заданий не удалось, используйте только сдачу в Stepik.
#
# ### Несколько замечаний по выполнению работы
# * Во всех пунктах указания это минимальный набор вещей, которые стоит сделать. Если вы можете сделать какой-то шаг лучше или добавить что-то свое --- дерзайте!
# * Пожалуйста, перед сдачей ноутбука убедитесь, что работа чистая и понятная. Это значительно облегчит проверку и повысит ваши ожидаемые баллы.
# * Если у вас будут проблемы с решением или хочется совета, то пишите в наш чат в телеграме.
#
#
# Данные: [train.csv](https://drive.google.com/file/d/1ERwQ5odiK1Zvi1LtjpkzCMUswYsAX8_K/view?usp=share_link),
# [test.csv](https://drive.google.com/file/d/1fGw_-RFwvn_LEdt91Jq-7A-wzG6mmH8r/view?usp=share_link), [submission.csv](https://drive.google.com/file/d/199Mt4OYZNaelT83U-HGDsEYs2YcUGQ6y/view?usp=share_link).
#
# Если ссылки на данные не работают, их можно скачать [на Kaggle](https://www.kaggle.com/competitions/advanced-dls-spring-2021/data).

# %% [markdown]
# # Как проверять?
#
# Ставьте полный балл, если выполнены все рекомендации или сделано что-то более интересное и сложное. За каждый отсустствующий пункт из рекомендации снижайте 1 балл.
#
# **Если решение верное, но не удовлетворяет вашим эстетическим предпочтениям, за это баллы снижать не нужно.**

# %% [markdown]
# # Метрика
#
# Перед решением любой задачи важно понимать, как будет оцениваться ваше решение. В данном случае мы используем стандартную для задачи классификации метрику ROC-AUC. Ее можно вычислить, используя только предсказанные вероятности и истинные классы без конкретного порога классификации + она раотает даже если классы в данных сильно несбалансированны (примеров одного класса в десятки раз больше примеров длугого). Именно поэтому она очень удобна для соревнований.
#
# Посчитать ее легко:

# %%
from sklearn.metrics import roc_auc_score

y_true = [
    0,
    1,
    1,
    0,
    1
]

y_predictions = [
    0.1,
    0.9,
    0.7,
    0.6,
    0.61
]

roc_auc_score(y_true, y_predictions)
# Out:
# 1.0

# %% [markdown]
# # Первая часть. Исследование

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Загрузка данных (2 балла)
#
# 1) Посмотрите на случайные строчки.
#
# 2) Посмотрите, есть ли в датасете незаполненные значения (nan'ы) с помощью data.isna() или data.info() и, если нужно, замените их на что-то. Будет хорошо, если вы построите табличку с количеством nan в каждой колонке.

# %%
# !gdown 1ERwQ5odiK1Zvi1LtjpkzCMUswYsAX8_K  # train.csv
# !gdown 1fGw_-RFwvn_LEdt91Jq-7A-wzG6mmH8r  # test.csv
# !gdown 199Mt4OYZNaelT83U-HGDsEYs2YcUGQ6y  # submission.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ERwQ5odiK1Zvi1LtjpkzCMUswYsAX8_K
# To: /content/train.csv
# 100% 664k/664k [00:00<00:00, 29.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1fGw_-RFwvn_LEdt91Jq-7A-wzG6mmH8r
# To: /content/test.csv
# 100% 218k/218k [00:00<00:00, 16.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=199Mt4OYZNaelT83U-HGDsEYs2YcUGQ6y
# To: /content/submission.csv
# 100% 14.7k/14.7k [00:00<00:00, 38.9MB/s]

# %%
data = pd.read_csv('./train.csv')

# %%
# Для вашего удобства списки с именами разных колонок

# Числовые признаки
num_cols = [
    'ClientPeriod',
    'MonthlySpending',
    'TotalSpent'
]

# Категориальные признаки
cat_cols = [
    'Sex',
    'IsSeniorCitizen',
    'HasPartner',
    'HasChild',
    'HasPhoneService',
    'HasMultiplePhoneNumbers',
    'HasInternetService',
    'HasOnlineSecurityService',
    'HasOnlineBackup',
    'HasDeviceProtection',
    'HasTechSupportAccess',
    'HasOnlineTV',
    'HasMovieSubscription',
    'HasContractPhone',
    'IsBillingPaperless',
    'PaymentMethod'
]

feature_cols = num_cols + cat_cols
target_col = 'Churn'

# %%
#1) Посмотрите на случайные строчки.
data.sample(n=5)

#2) Посмотрите, есть ли в датасете незаполненные значения (nan'ы) с помощью
#data.isna() или data.info() и, если нужно, замените их на что-то. Будет хорошо,
#если вы построите табличку с количеством nan в каждой колонке.

data.info()
data.shape

#Незаполненные значения отсутствуют
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5282 entries, 0 to 5281
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ClientPeriod              5282 non-null   int64
#  1   MonthlySpending           5282 non-null   float64
#  2   TotalSpent                5282 non-null   object
#  3   Sex                       5282 non-null   object
#  4   IsSeniorCitizen           5282 non-null   int64
#  5   HasPartner                5282 non-null   object
#  6   HasChild                  5282 non-null   object
#  7   HasPhoneService           5282 non-null   object
#  8   HasMultiplePhoneNumbers   5282 non-null   object
#  9   HasInternetService        5282 non-null   object
#  10  HasOnlineSecurityService  5282 non-null   object
#  11  HasOnlineBackup           5282 non-null   object
#  12  HasDeviceProtection       5282 non-null   object
#  13  HasTechSupportAccess      5282 non-null   object
#  14  HasOnlineTV               5282 non-null   object
#  15  HasMovieSubscription      5282 non-null   object
#  16  HasContractPhone          5282 non-null   object
#  17  IsBillingPaperless        5282 non-null   object
#  18  PaymentMethod             5282 non-null   object
#  19  Churn                     5282 non-null   int64
# dtypes: float64(1), int64(3), object(16)
# memory usage: 825.4+ KB
# (5282, 20)

# %% [markdown]
# ## Анализ данных (3 балла)
#
# 1) Для численных призанков постройте гистограмму (*plt.hist(...)*) или boxplot (*plt.boxplot(...)*). Для категориальных посчитайте количество каждого значения для каждого признака. Для каждой колонки надо сделать *data.value_counts()* и построить bar диаграммы *plt.bar(...)* или круговые диаграммы *plt.pie(...)* (хорошо, елси вы сможете это сделать на одном гарфике с помощью *plt.subplots(...)*).
#
# 2) Посмотрите на распределение целевой переменной и скажите, являются ли классы несбалансированными.
#
# 3) (Если будет желание) Поиграйте с разными библиотеками для визуализации - *sns*, *pandas_visual_analysis*, etc.
#
# Второй пункт очень важен, потому что существуют задачи классификации с несбалансированными классами. Например, это может значить, что в датасете намного больше примеров 0 класса. В таких случаях нужно 1) не использовать accuracy как метрику 2) использовать методы борьбы с imbalanced dataset (обычно если датасет сильно несбалансирован, т.е. класса 1 в 20 раз меньше класса 0).

# %%
#1) Для численных признаков постройте гистограмму (plt.hist(...)) или
#boxplot (plt.boxplot(...)). Для категориальных посчитайте количество
#каждого значения для каждого признака. Для каждой колонки надо сделать
#data.value_counts() и построить bar диаграммы plt.bar(...) или круговые
#диаграммы plt.pie(...) (хорошо, елси вы сможете это сделать на одном
#графике с помощью plt.subplots(...)).

settings = {
    "bins": 100,
    "plot_size" : {"width": 7, "height": 5},
}

plt.figure(
    figsize=(settings["plot_size"]["width"], settings["plot_size"]["height"]))

for i, feature in enumerate(num_cols):
    plt.subplot(len(num_cols), 1, i + 1)
    plt.hist(data[feature], bins=settings["bins"])
    plt.xlabel(feature)
    plt.ylabel('Частота')
    plt.title(f'Гистограмма для {feature}')

plt.tight_layout()
plt.show()

# %%
settings = {
    "bins": 100,
    "plot_size" : {"width": 12, "height": 30},
}

plt.figure(
    figsize=(settings["plot_size"]["width"], settings["plot_size"]["height"]))


for i, col in enumerate(cat_cols):
    plt.subplot(len(cat_cols), 3, i + 1)
    value_counts = data[col].value_counts()
    labels = value_counts.index
    sizes = value_counts.values
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=60)
    plt.title(f'Распределение {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# (Дополнительно) Если вы нашли какие-то ошибки в данных или выбросы, то можете их убрать. Тут можно поэксперементировать с обработкой данных как угодно, но не за баллы.

# %%
data["TotalSpent"] = pd.to_numeric(data["TotalSpent"], errors="coerce")

# %%
#Удаляем записи с пустыми TotalSpent
data.drop(data[data['TotalSpent'].isna()].index, inplace=True)

# %% [markdown]
# ## Применение линейных моделей (3 балла)
#
# 1) Обработайте данные для того, чтобы к ним можно было применить LogisticRegression. Т.е. отнормируйте числовые признаки, а категориальные закодируйте с помощью one-hot-encoding'а.
#
# 2) С помощью кроссвалидации или разделения на train/valid выборку протестируйте разные значения гиперпараметра C и выберите лучший (можно тестировать С=100, 10, 1, 0.1, 0.01, 0.001) по метрике ROC-AUC.
#
# Если вы разделяете на train/valid, то используйте LogisticRegressionCV. Он сам при вызове .fit() подберет параметр С. (не забудьте передать scroing='roc_auc', чтобы при кроссвалидации сравнивались значения этой метрики, и refit=True, чтобы при потом модель обучилась на всем датасете с лучшим параметром C).
#
#
# (более сложный вариант) Если вы будете использовать кроссвалидацию, то преобразования данных и LogisticRegression нужно соединить в один Pipeline с помощью make_pipeline, как это делалось во втором семинаре. Потом pipeline надо передать в GridSearchCV. Для one-hot-encoding'a можно испльзовать комбинацию LabelEncoder + OneHotEncoder (сначала превращаем строчки в числа, а потом числа првращаем в one-hot вектора.)

# %%
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder, OneHotEncoder
from sklearn.pipeline import make_pipeline

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder())
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, num_cols),
        ('cat', categorical_transformer, cat_cols)
    ])

pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

X = pipeline.fit_transform(data.drop(columns=[target_col]))
y = data[target_col]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score


C_values = [100, 10, 1, 0.1, 0.01, 0.001]
roc_auc_scores = {}

for C in C_values:
    model = LogisticRegression(C=C)
    cv_scores = cross_val_score(model, X, y, cv=5, scoring='roc_auc')
    roc_auc_scores[C] = cv_scores.mean()


best_C = max(roc_auc_scores, key=roc_auc_scores.get)

print("Результаты кросс-валидации:")
for C, roc_auc in roc_auc_scores.items():
    print(f"C = {C}: ROC-AUC = {roc_auc}")

print(f"Лучший C: {best_C} с ROC-AUC = {roc_auc_scores[best_C]}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Результаты кросс-валидации:
# C = 100: ROC-AUC = 0.8448208899368537
# C = 10: ROC-AUC = 0.8448265075092574
# C = 1: ROC-AUC = 0.8447152485602236
# C = 0.1: ROC-AUC = 0.8438174042185068
# C = 0.01: ROC-AUC = 0.8412947046859791
# C = 0.001: ROC-AUC = 0.8372018918620163
# Лучший C: 10 с ROC-AUC = 0.8448265075092574

# %%
model = LogisticRegression()
pipeline = make_pipeline(preprocessor, model)
param_grid = {'logisticregression__C': [100, 10, 1, 0.1, 0.01, 0.001]}
grid_search = GridSearchCV(pipeline, param_grid, scoring='roc_auc', cv=10)
grid_search.fit(data.drop(target_col, axis=1), data[target_col])
print("Лучший параметр C:", grid_search.best_params_)
print("Лучший ROC-AUC:", grid_search.best_score_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Лучший параметр C: {'logisticregression__C': 10}
# Лучший ROC-AUC: 0.8446241270756658

# %%
grid_search.__dict__
# Out:
# {'scoring': 'roc_auc',
#  'estimator': Pipeline(steps=[('columntransformer',
#                   ColumnTransformer(transformers=[('num',
#                                                    Pipeline(steps=[('scaler',
#                                                                     StandardScaler())]),
#                                                    ['ClientPeriod',
#                                                     'MonthlySpending',
#                                                     'TotalSpent']),
#                                                   ('cat',
#                                                    Pipeline(steps=[('onehot',
#                                                                     OneHotEncoder())]),
#                                                    ['Sex', 'IsSeniorCitizen',
#                                                     'HasPartner', 'HasChild',
#                                                     'HasPhoneService',
#                                                     'HasMultiplePhoneNumbers',
#                                                     'HasInternetService',
#                                                     'HasOnlineSecurityService',
#                                                     'HasOnlineBackup',
#                                                     'HasDeviceProtection',
#                                                     'HasTechSupportAccess',
#                                                     'HasOnlineTV',
#                                                     'HasMovieSubscription',
#                                                     'HasContractPhone',
#                                                     'IsBillingPaperless',
#                                                     'PaymentMethod'])])),
#                  ('logisticregression', LogisticRegression())]),
#  'n_jobs': None,
#  'refit': True,
#  'cv': 10,
#  'verbose': 0,
#  'pre_dispatch': '2*n_jobs',
#  'error_score': nan,
#  'return_train_score': False,
#  'param_grid': {'logisticregression__C': [100, 10, 1, 0.1, 0.01, 0.001]},
#  'multimetric_': False,
#  'best_index_': 1,
#  'best_score_': 0.8446241270756658,
#  'best_params_': {'logisticregression__C': 10},
#  'best_estimator_': Pipeline(steps=[('columntransformer',
#                   ColumnTransformer(transformers=[('num',
#                                                    Pipeline(steps=[('scaler',
#                                                                     StandardScaler())]),
#                                                    ['ClientPeriod',
#                                                     'MonthlySpending',
#                                                     'TotalSpent']),
#                                                   ('cat',
#                                                    Pipeline(steps=[('onehot',
#                                                                     OneHotEncoder())]),
#                                                    ['Sex', 'IsSeniorCitizen',
#                                                     'HasPartner', 'HasChild',
#                                                     'HasPhoneService',
#                                                     'HasMultiplePhoneNumbers',
#                                                     'HasInternetService',
#                                                     'HasOnlineSecurityService',
#                                                     'HasOnlineBackup',
#                                                     'HasDeviceProtection',
#                                                     'HasTechSupportAccess',
#                                                     'HasOnlineTV',
#                                                     'HasMovieSubscription',
#                                                     'HasContractPhone',
#                                                     'IsBillingPaperless',
#                                                     'PaymentMethod'])])),
#                  ('logisticregression', LogisticRegression(C=10))]),
#  'refit_time_': 0.05989980697631836,
#  'feature_names_in_': array(['ClientPeriod', 'MonthlySpending', 'TotalSpent', 'Sex',
#         'IsSeniorCitizen', 'HasPartner', 'HasChild', 'HasPhoneService',
#         'HasMultiplePhoneNumbers', 'HasInternetService',
#         'HasOnlineSecurityService', 'HasOnlineBackup',
#         'HasDeviceProtection', 'HasTechSupportAccess', 'HasOnlineTV',
#         'HasMovieSubscription', 'HasContractPhone', 'IsBillingPaperless',
#         'PaymentMethod'], dtype=object),
#  'scorer_': make_scorer(roc_auc_score, needs_threshold=True),
#  'cv_results_': {'mean_fit_time': array([0.0646112 , 0.07701619, 0.15013335, 0.13143177, 0.04901905,
#          0.04238458]),
#   'std_fit_time': array([0.00628776, 0.01709783, 0.00705764, 0.03362682, 0.00678877,
#          0.00565029]),
#   'mean_score_time': array([0.011059  , 0.0114255 , 0.02175567, 0.02027767, 0.01063607,
#          0.01000752]),
#   'std_score_time': array([0.00098542, 0.00106677, 0.00189834, 0.01260978, 0.00069685,
#          0.00057376]),
#   'param_logisticregression__C': masked_array(data=[100, 10, 1, 0.1, 0.01, 0.001],
#                mask=[False, False, False, False, False, False],
#          fill_value='?',
#               dtype=object),
#   'params': [{'logisticregression__C': 100},
#    {'logisticregression__C': 10},
#    {'logisticregression__C': 1},
#    {'logisticregression__C': 0.1},
#    {'logisticregression__C': 0.01},
#    {'logisticregression__C': 0.001}],
#   'split0_test_score': array([0.85065932, 0.85052986, 0.85003052, 0.84808862, 0.84193005,
#          0.83549407]),
#   'split1_test_score': array([0.87129885, 0.87120638, 0.87103993, 0.87052209, 0.86895008,
#          0.86375321]),
#   'split2_test_score': array([0.84686801, 0.84681252, 0.84640565, 0.8446672 , 0.83719554,
#          0.82665384]),
#   'split3_test_score': array([0.82554674, 0.82550948, 0.82547223, 0.8260497 , 0.82889982,
#          0.82837823]),
#   'split4_test_score': array([0.8477702 , 0.84754666, 0.84674565, 0.84627994, 0.84635446,
#          0.85013599]),
#   'split5_test_score': array([0.82198875, 0.82219366, 0.82217503, 0.8225476 , 0.81990239,
#          0.81440706]),
#   'split6_test_score': array([0.84745352, 0.84734175, 0.8470437 , 0.84652211, 0.8469133 ,
#          0.84668977]),
#   'split7_test_score': array([0.86373459, 0.86410715, 0.86451697, 0.8659886 , 0.86326888,
#          0.85546366]),
#   'split8_test_score': array([0.83996498, 0.84015126, 0.83966693, 0.83962967, 0.83894043,
#          0.83771096]),
#   'split9_test_score': array([0.83074983, 0.83084254, 0.83056441, 0.82863606, 0.82144182,
#          0.81613884]),
#   'mean_test_score': array([0.84460348, 0.84462413, 0.8443661 , 0.84389316, 0.84137968,
#          0.83748256]),
#   'std_test_score': array([0.01492186, 0.01490044, 0.01492856, 0.01501032, 0.01527394,
#          0.01565419]),
#   'rank_test_score': array([2, 1, 3, 4, 5, 6], dtype=int32)},
#  'n_splits_': 10}

# %% [markdown]
# Выпишите какое лучшее качество и с какими параметрами вам удалось получить

# %% [markdown]
# ## Применение градиентного бустинга (2 балла)
#
# Если вы хотите получить баллы за точный ответ, то стоит попробовать градиентный бустинг. Часто градиентный бустинг с параметрами по умолчанию даст вам 80% результата за 0% усилий.
#
# Мы будем использовать catboost, поэтому нам не надо кодировать категориальные признаки. Catboost сделает это сам (в .fit() надо передать cat_features=cat_cols). А численные признаки нормировать для моделей, основанных на деревьях не нужно.
#
# 1) Разделите выборку на train/valid. Протестируйте catboost cо стандартными параметрами.
#
# 2) Протестируйте разные занчения параметроа количества деревьев и learning_rate'а и выберите лучшую по метрике ROC-AUC комбинацию.
#
# (Дополнительно) Есть некоторые сложности с тем, чтобы использовать CatBoostClassifier вместе с GridSearchCV, поэтому мы не просим использовать кроссвалидацию. Но можете попробовать)

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)

# %%
import catboost # документация: https://catboost.ai/docs

X_train_origin, X_test_origin, y_train, y_test = train_test_split(
    data.drop(target_col, axis=1), data[target_col],
    train_size=0.8,
    random_state=42)

# %%
boosting_model = catboost.CatBoostClassifier(n_estimators=200,
                                             cat_features=cat_cols)

boosting_model.fit(X_train_origin, y_train)

y_train_predicted = boosting_model.predict_proba(X_train_origin)[:, 1]
y_test_predicted = boosting_model.predict_proba(X_test_origin)[:, 1]
# Out:
# Learning rate set to 0.083332
# 0:	learn: 0.6393850	total: 15.6ms	remaining: 3.11s
# 1:	learn: 0.5986678	total: 27.5ms	remaining: 2.72s
# 2:	learn: 0.5669397	total: 34.7ms	remaining: 2.28s
# 3:	learn: 0.5401092	total: 45.6ms	remaining: 2.23s
# 4:	learn: 0.5184259	total: 57.4ms	remaining: 2.24s
# 5:	learn: 0.5006508	total: 67.3ms	remaining: 2.17s
# 6:	learn: 0.4860068	total: 84.5ms	remaining: 2.33s
# 7:	learn: 0.4729220	total: 100ms	remaining: 2.4s
# 8:	learn: 0.4613053	total: 112ms	remaining: 2.39s
# 9:	learn: 0.4518849	total: 123ms	remaining: 2.33s
# 10:	learn: 0.4444709	total: 153ms	remaining: 2.63s
# 11:	learn: 0.4389258	total: 162ms	remaining: 2.54s
# 12:	learn: 0.4351742	total: 170ms	remaining: 2.44s
# 13:	learn: 0.4308061	total: 178ms	remaining: 2.37s
# 14:	learn: 0.4263292	total: 190ms	remaining: 2.34s
# 15:	learn: 0.4224699	total: 204ms	remaining: 2.34s
# 16:	learn: 0.4199115	total: 212ms	remaining: 2.28s
# 17:	learn: 0.4175362	total: 222ms	remaining: 2.25s
# 18:	learn: 0.4142761	total: 233ms	remaining: 2.22s
# 19:	learn: 0.4125824	total: 242ms	remaining: 2.18s
# 20:	learn: 0.4106805	total: 252ms	remaining: 2.14s
# 21:	learn: 0.4100943	total: 257ms	remaining: 2.08s
# 22:	learn: 0.4086343	total: 268ms	remaining: 2.06s
# 23:	learn: 0.4068653	total: 278ms	remaining: 2.04s
# 24:	learn: 0.4053385	total: 287ms	remaining: 2.01s
# 25:	learn: 0.4040037	total: 297ms	remaining: 1.99s
# 26:	learn: 0.4032561	total: 305ms	remaining: 1.96s
# 27:	learn: 0.4024138	total: 312ms	remaining: 1.92s
# 28:	learn: 0.4008988	total: 319ms	remaining: 1.88s
# 29:	learn: 0.4001330	total: 326ms	remaining: 1.85s
# 30:	learn: 0.3998920	total: 331ms	remaining: 1.8s
# 31:	learn: 0.3986352	total: 343ms	remaining: 1.8s
# 32:	learn: 0.3984955	total: 348ms	remaining: 1.76s
# 33:	learn: 0.3974771	total: 357ms	remaining: 1.74s
# 34:	learn: 0.3966830	total: 365ms	remaining: 1.72s
# 35:	learn: 0.3964145	total: 370ms	remaining: 1.68s
# 36:	learn: 0.3958449	total: 379ms	remaining: 1.67s
# 37:	learn: 0.3951034	total: 388ms	remaining: 1.65s
# 38:	learn: 0.3940753	total: 397ms	remaining: 1.64s
# 39:	learn: 0.3939314	total: 405ms	remaining: 1.62s
# 40:	learn: 0.3933080	total: 415ms	remaining: 1.61s
# 41:	learn: 0.3925020	total: 424ms	remaining: 1.6s
# 42:	learn: 0.3925013	total: 426ms	remaining: 1.56s
# 43:	learn: 0.3922959	total: 435ms	remaining: 1.54s
# 44:	learn: 0.3916142	total: 445ms	remaining: 1.53s
# 45:	learn: 0.3908284	total: 454ms	remaining: 1.52s
# 46:	learn: 0.3904076	total: 464ms	remaining: 1.51s
# 47:	learn: 0.3894747	total: 479ms	remaining: 1.51s
# 48:	learn: 0.3890743	total: 490ms	remaining: 1.51s
# 49:	learn: 0.3885796	total: 500ms	remaining: 1.5s
# 50:	learn: 0.3885796	total: 502ms	remaining: 1.47s
# 51:	learn: 0.3877753	total: 511ms	remaining: 1.45s
# 52:	learn: 0.3875378	total: 522ms	remaining: 1.45s
# 53:	learn: 0.3867899	total: 531ms	remaining: 1.44s
# 54:	learn: 0.3862942	total: 541ms	remaining: 1.43s
# 55:	learn: 0.3862692	total: 545ms	remaining: 1.4s
# 56:	learn: 0.3860733	total: 550ms	remaining: 1.38s
# 57:	learn: 0.3859114	total: 558ms	remaining: 1.37s
# 58:	learn: 0.3858461	total: 563ms	remaining: 1.34s
# 59:	learn: 0.3855916	total: 571ms	remaining: 1.33s
# 60:	learn: 0.3848055	total: 580ms	remaining: 1.32s
# 61:	learn: 0.3840814	total: 589ms	remaining: 1.31s
# 62:	learn: 0.3840254	total: 597ms	remaining: 1.3s
# 63:	learn: 0.3839906	total: 601ms	remaining: 1.28s
# 64:	learn: 0.3837327	total: 614ms	remaining: 1.28s
# 65:	learn: 0.3833261	total: 624ms	remaining: 1.27s
# 66:	learn: 0.3825917	total: 632ms	remaining: 1.25s
# 67:	learn: 0.3823562	total: 642ms	remaining: 1.25s
# 68:	learn: 0.3817686	total: 651ms	remaining: 1.24s
# 69:	learn: 0.3816211	total: 663ms	remaining: 1.23s
# 70:	learn: 0.3813737	total: 673ms	remaining: 1.22s
# 71:	learn: 0.3813502	total: 675ms	remaining: 1.2s
# 72:	learn: 0.3808819	total: 684ms	remaining: 1.19s
# 73:	learn: 0.3798934	total: 693ms	remaining: 1.18s
# 74:	learn: 0.3794574	total: 702ms	remaining: 1.17s
# 75:	learn: 0.3793537	total: 706ms	remaining: 1.15s
# 76:	learn: 0.3788948	total: 714ms	remaining: 1.14s
# 77:	learn: 0.3783271	total: 723ms	remaining: 1.13s
# 78:	learn: 0.3780525	total: 732ms	remaining: 1.12s
# 79:	learn: 0.3779892	total: 737ms	remaining: 1.1s
# 80:	learn: 0.3772354	total: 746ms	remaining: 1.09s
# 81:	learn: 0.3766600	total: 755ms	remaining: 1.09s
# 82:	learn: 0.3761457	total: 764ms	remaining: 1.08s
# 83:	learn: 0.3761402	total: 768ms	remaining: 1.06s
# 84:	learn: 0.3761153	total: 775ms	remaining: 1.05s
# 85:	learn: 0.3757109	total: 784ms	remaining: 1.04s
# 86:	learn: 0.3755057	total: 793ms	remaining: 1.03s
# 87:	learn: 0.3752161	total: 802ms	remaining: 1.02s
# 88:	learn: 0.3749418	total: 811ms	remaining: 1.01s
# 89:	learn: 0.3743063	total: 826ms	remaining: 1.01s
# 90:	learn: 0.3741375	total: 835ms	remaining: 1s
# 91:	learn: 0.3735867	total: 843ms	remaining: 989ms
# 92:	learn: 0.3728390	total: 852ms	remaining: 981ms
# 93:	learn: 0.3726758	total: 862ms	remaining: 972ms
# 94:	learn: 0.3718457	total: 871ms	remaining: 963ms
# 95:	learn: 0.3714807	total: 880ms	remaining: 953ms
# 96:	learn: 0.3712320	total: 897ms	remaining: 953ms
# 97:	learn: 0.3711793	total: 936ms	remaining: 975ms
# 98:	learn: 0.3708805	total: 975ms	remaining: 995ms
# 99:	learn: 0.3705140	total: 999ms	remaining: 999ms
# 100:	learn: 0.3702073	total: 1.02s	remaining: 1s
# 101:	learn: 0.3696133	total: 1.05s	remaining: 1.01s
# 102:	learn: 0.3687721	total: 1.1s	remaining: 1.04s
# 103:	learn: 0.3684416	total: 1.14s	remaining: 1.05s
# 104:	learn: 0.3681062	total: 1.18s	remaining: 1.07s
# 105:	learn: 0.3676945	total: 1.2s	remaining: 1.07s
# 106:	learn: 0.3674837	total: 1.23s	remaining: 1.07s
# 107:	learn: 0.3670150	total: 1.25s	remaining: 1.07s
# 108:	learn: 0.3666500	total: 1.27s	remaining: 1.06s
# 109:	learn: 0.3658847	total: 1.28s	remaining: 1.05s
# 110:	learn: 0.3651169	total: 1.29s	remaining: 1.03s
# 111:	learn: 0.3642514	total: 1.31s	remaining: 1.03s
# 112:	learn: 0.3636622	total: 1.32s	remaining: 1.01s
# 113:	learn: 0.3633506	total: 1.33s	remaining: 1s
# 114:	learn: 0.3627703	total: 1.34s	remaining: 990ms
# 115:	learn: 0.3618978	total: 1.35s	remaining: 976ms
# 116:	learn: 0.3615906	total: 1.36s	remaining: 964ms
# 117:	learn: 0.3610257	total: 1.37s	remaining: 951ms
# 118:	learn: 0.3604401	total: 1.38s	remaining: 938ms
# 119:	learn: 0.3594542	total: 1.39s	remaining: 925ms
# 120:	learn: 0.3588681	total: 1.4s	remaining: 912ms
# 121:	learn: 0.3586290	total: 1.41s	remaining: 900ms
# 122:	learn: 0.3583895	total: 1.42s	remaining: 888ms
# 123:	learn: 0.3579040	total: 1.43s	remaining: 879ms
# 124:	learn: 0.3576181	total: 1.45s	remaining: 869ms
# 125:	learn: 0.3571910	total: 1.46s	remaining: 858ms
# 126:	learn: 0.3566694	total: 1.47s	remaining: 846ms
# 127:	learn: 0.3563513	total: 1.49s	remaining: 837ms
# 128:	learn: 0.3558232	total: 1.5s	remaining: 825ms
# 129:	learn: 0.3552659	total: 1.51s	remaining: 814ms
# 130:	learn: 0.3541500	total: 1.52s	remaining: 803ms
# 131:	learn: 0.3535561	total: 1.54s	remaining: 791ms
# 132:	learn: 0.3532243	total: 1.55s	remaining: 780ms
# 133:	learn: 0.3526529	total: 1.56s	remaining: 767ms
# 134:	learn: 0.3521707	total: 1.57s	remaining: 755ms
# 135:	learn: 0.3515384	total: 1.58s	remaining: 743ms
# 136:	learn: 0.3509887	total: 1.59s	remaining: 731ms
# 137:	learn: 0.3504353	total: 1.6s	remaining: 719ms
# 138:	learn: 0.3501934	total: 1.61s	remaining: 706ms
# 139:	learn: 0.3497991	total: 1.62s	remaining: 694ms
# 140:	learn: 0.3496516	total: 1.63s	remaining: 681ms
# 141:	learn: 0.3491151	total: 1.64s	remaining: 669ms
# 142:	learn: 0.3487621	total: 1.65s	remaining: 657ms
# 143:	learn: 0.3486158	total: 1.66s	remaining: 644ms
# 144:	learn: 0.3482835	total: 1.67s	remaining: 634ms
# 145:	learn: 0.3479918	total: 1.68s	remaining: 622ms
# 146:	learn: 0.3478319	total: 1.69s	remaining: 611ms
# 147:	learn: 0.3477123	total: 1.7s	remaining: 599ms
# 148:	learn: 0.3472270	total: 1.71s	remaining: 586ms
# 149:	learn: 0.3470823	total: 1.72s	remaining: 574ms
# 150:	learn: 0.3466258	total: 1.73s	remaining: 562ms
# 151:	learn: 0.3464967	total: 1.74s	remaining: 550ms
# 152:	learn: 0.3459971	total: 1.75s	remaining: 538ms
# 153:	learn: 0.3458168	total: 1.76s	remaining: 526ms
# 154:	learn: 0.3454995	total: 1.77s	remaining: 514ms
# 155:	learn: 0.3452478	total: 1.78s	remaining: 502ms
# 156:	learn: 0.3451798	total: 1.79s	remaining: 491ms
# 157:	learn: 0.3448005	total: 1.8s	remaining: 479ms
# 158:	learn: 0.3440715	total: 1.82s	remaining: 469ms
# 159:	learn: 0.3436916	total: 1.83s	remaining: 457ms
# 160:	learn: 0.3434870	total: 1.84s	remaining: 445ms
# 161:	learn: 0.3432215	total: 1.85s	remaining: 433ms
# 162:	learn: 0.3430880	total: 1.86s	remaining: 422ms
# 163:	learn: 0.3427581	total: 1.87s	remaining: 410ms
# 164:	learn: 0.3424597	total: 1.88s	remaining: 399ms
# 165:	learn: 0.3423600	total: 1.89s	remaining: 388ms
# 166:	learn: 0.3420330	total: 1.9s	remaining: 376ms
# 167:	learn: 0.3416798	total: 1.92s	remaining: 365ms
# 168:	learn: 0.3412737	total: 1.93s	remaining: 353ms
# 169:	learn: 0.3404688	total: 1.94s	remaining: 342ms
# 170:	learn: 0.3399286	total: 1.95s	remaining: 330ms
# 171:	learn: 0.3395102	total: 1.96s	remaining: 319ms
# 172:	learn: 0.3392105	total: 1.97s	remaining: 307ms
# 173:	learn: 0.3389528	total: 1.98s	remaining: 296ms
# 174:	learn: 0.3385231	total: 1.99s	remaining: 284ms
# 175:	learn: 0.3382915	total: 2s	remaining: 273ms
# 176:	learn: 0.3374019	total: 2.01s	remaining: 261ms
# 177:	learn: 0.3369077	total: 2.02s	remaining: 250ms
# 178:	learn: 0.3366573	total: 2.03s	remaining: 238ms
# 179:	learn: 0.3364366	total: 2.04s	remaining: 227ms
# 180:	learn: 0.3360432	total: 2.05s	remaining: 215ms
# 181:	learn: 0.3355215	total: 2.06s	remaining: 204ms
# 182:	learn: 0.3353405	total: 2.1s	remaining: 195ms
# 183:	learn: 0.3347534	total: 2.13s	remaining: 186ms
# 184:	learn: 0.3344863	total: 2.15s	remaining: 175ms
# 185:	learn: 0.3343503	total: 2.17s	remaining: 164ms
# 186:	learn: 0.3338920	total: 2.2s	remaining: 153ms
# 187:	learn: 0.3334944	total: 2.22s	remaining: 142ms
# 188:	learn: 0.3327864	total: 2.25s	remaining: 131ms
# 189:	learn: 0.3327116	total: 2.27s	remaining: 120ms
# 190:	learn: 0.3325706	total: 2.3s	remaining: 108ms
# 191:	learn: 0.3324350	total: 2.32s	remaining: 96.7ms
# 192:	learn: 0.3321759	total: 2.34s	remaining: 84.8ms
# 193:	learn: 0.3319562	total: 2.35s	remaining: 72.6ms
# 194:	learn: 0.3316261	total: 2.36s	remaining: 60.5ms
# 195:	learn: 0.3314515	total: 2.37s	remaining: 48.3ms
# 196:	learn: 0.3307845	total: 2.38s	remaining: 36.2ms
# 197:	learn: 0.3304574	total: 2.39s	remaining: 24.1ms
# 198:	learn: 0.3297162	total: 2.39s	remaining: 12ms
# 199:	learn: 0.3294067	total: 2.4s	remaining: 0us

# %%
from sklearn.metrics import roc_auc_score, roc_curve

train_auc = roc_auc_score(y_train, y_train_predicted)
test_auc = roc_auc_score(y_test, y_test_predicted)

plt.figure(figsize=(10,7))
plt.plot(*roc_curve(y_train, y_train_predicted)[:2], label='train AUC={:.4f}'.format(train_auc))
plt.plot(*roc_curve(y_test, y_test_predicted)[:2], label='test AUC={:.4f}'.format(test_auc))
legend_box = plt.legend(fontsize='large', framealpha=1).get_frame()
legend_box.set_facecolor("white")
legend_box.set_edgecolor("black")
plt.plot(np.linspace(0,1,100), np.linspace(0,1,100))
plt.show()

# %%
model = catboost.CatBoostClassifier(
    cat_features=cat_cols)

parameters = {'depth'         : [6, 7, 8],
              'learning_rate' : [0.08, 0.084, 0.086],
              'iterations'    : [73, 74, 75],
              'random_state'  : [36, 42, 50],
              }

result = GridSearchCV(
    estimator=model,
    param_grid = parameters,
    cv = 2,
    n_jobs=-1)
result.fit(X_train_origin, y_train)

print("Results from Grid Search")
print("\n The best estimator across ALL searched params:\n",result.best_estimator_)
print("\n The best score across ALL searched params:\n",result.best_score_)
print("\n The best parameters across ALL searched params:\n",result.best_params_)
# Out:
# 0:	learn: 0.6639232	total: 6.82ms	remaining: 498ms
# 1:	learn: 0.6372257	total: 12.3ms	remaining: 444ms
# 2:	learn: 0.6152199	total: 16.8ms	remaining: 397ms
# 3:	learn: 0.5957478	total: 20.7ms	remaining: 363ms
# 4:	learn: 0.5777173	total: 24.7ms	remaining: 341ms
# 5:	learn: 0.5621432	total: 28.9ms	remaining: 328ms
# 6:	learn: 0.5485029	total: 33.5ms	remaining: 320ms
# 7:	learn: 0.5360779	total: 37.6ms	remaining: 310ms
# 8:	learn: 0.5265280	total: 41.6ms	remaining: 301ms
# 9:	learn: 0.5173250	total: 45.8ms	remaining: 293ms
# 10:	learn: 0.5082034	total: 49.9ms	remaining: 286ms
# 11:	learn: 0.4988180	total: 54.1ms	remaining: 280ms
# 12:	learn: 0.4905047	total: 58.3ms	remaining: 274ms
# 13:	learn: 0.4825199	total: 61.3ms	remaining: 263ms
# 14:	learn: 0.4756461	total: 63.8ms	remaining: 251ms
# 15:	learn: 0.4694083	total: 66.9ms	remaining: 243ms
# 16:	learn: 0.4644555	total: 68.6ms	remaining: 230ms
# 17:	learn: 0.4597120	total: 71.8ms	remaining: 223ms
# 18:	learn: 0.4551656	total: 75.9ms	remaining: 220ms
# 19:	learn: 0.4518240	total: 77.2ms	remaining: 208ms
# 20:	learn: 0.4485458	total: 81.5ms	remaining: 206ms
# 21:	learn: 0.4446919	total: 88.3ms	remaining: 209ms
# 22:	learn: 0.4408861	total: 96.2ms	remaining: 213ms
# 23:	learn: 0.4380844	total: 101ms	remaining: 210ms
# 24:	learn: 0.4350296	total: 106ms	remaining: 208ms
# 25:	learn: 0.4331451	total: 108ms	remaining: 199ms
# 26:	learn: 0.4304254	total: 112ms	remaining: 195ms
# 27:	learn: 0.4279929	total: 116ms	remaining: 191ms
# 28:	learn: 0.4256261	total: 121ms	remaining: 187ms
# 29:	learn: 0.4233036	total: 125ms	remaining: 183ms
# 30:	learn: 0.4221376	total: 127ms	remaining: 176ms
# 31:	learn: 0.4211843	total: 128ms	remaining: 168ms
# 32:	learn: 0.4194583	total: 132ms	remaining: 164ms
# 33:	learn: 0.4183977	total: 134ms	remaining: 158ms
# 34:	learn: 0.4170920	total: 137ms	remaining: 153ms
# 35:	learn: 0.4158026	total: 141ms	remaining: 149ms
# 36:	learn: 0.4142483	total: 145ms	remaining: 145ms
# 37:	learn: 0.4129396	total: 149ms	remaining: 141ms
# 38:	learn: 0.4117144	total: 152ms	remaining: 137ms
# 39:	learn: 0.4109136	total: 154ms	remaining: 131ms
# 40:	learn: 0.4102547	total: 156ms	remaining: 125ms
# 41:	learn: 0.4090311	total: 160ms	remaining: 122ms
# 42:	learn: 0.4085869	total: 163ms	remaining: 117ms
# 43:	learn: 0.4073593	total: 167ms	remaining: 114ms
# 44:	learn: 0.4068979	total: 169ms	remaining: 109ms
# 45:	learn: 0.4057452	total: 173ms	remaining: 105ms
# 46:	learn: 0.4052686	total: 175ms	remaining: 100ms
# 47:	learn: 0.4043241	total: 179ms	remaining: 96.9ms
# 48:	learn: 0.4041344	total: 181ms	remaining: 92.2ms
# 49:	learn: 0.4029518	total: 185ms	remaining: 88.7ms
# 50:	learn: 0.4022248	total: 190ms	remaining: 85.5ms
# 51:	learn: 0.4013413	total: 194ms	remaining: 82ms
# 52:	learn: 0.4004527	total: 199ms	remaining: 78.7ms
# 53:	learn: 0.4001687	total: 207ms	remaining: 76.7ms
# 54:	learn: 0.3999657	total: 209ms	remaining: 72.2ms
# 55:	learn: 0.3992205	total: 213ms	remaining: 68.5ms
# 56:	learn: 0.3990475	total: 215ms	remaining: 64ms
# 57:	learn: 0.3984073	total: 219ms	remaining: 60.3ms
# 58:	learn: 0.3977709	total: 224ms	remaining: 56.9ms
# 59:	learn: 0.3971853	total: 229ms	remaining: 53.4ms
# 60:	learn: 0.3966319	total: 233ms	remaining: 49.7ms
# 61:	learn: 0.3964460	total: 237ms	remaining: 46ms
# 62:	learn: 0.3955706	total: 242ms	remaining: 42.2ms
# 63:	learn: 0.3951914	total: 244ms	remaining: 38.1ms
# 64:	learn: 0.3947735	total: 248ms	remaining: 34.4ms
# 65:	learn: 0.3941322	total: 253ms	remaining: 30.6ms
# 66:	learn: 0.3935840	total: 258ms	remaining: 26.9ms
# 67:	learn: 0.3933589	total: 260ms	remaining: 23ms
# 68:	learn: 0.3929094	total: 265ms	remaining: 19.2ms
# 69:	learn: 0.3925918	total: 269ms	remaining: 15.3ms
# 70:	learn: 0.3924041	total: 272ms	remaining: 11.5ms
# 71:	learn: 0.3923344	total: 274ms	remaining: 7.61ms
# 72:	learn: 0.3917657	total: 278ms	remaining: 3.81ms
# 73:	learn: 0.3917456	total: 280ms	remaining: 0us
# Results from Grid Search
#
#  The best estimator across ALL searched params:
#  <catboost.core.CatBoostClassifier object at 0x7992c7659ba0>
#
#  The best score across ALL searched params:
#  0.8046467520151731
#
#  The best parameters across ALL searched params:
#  {'depth': 7, 'iterations': 74, 'learning_rate': 0.084, 'random_state': 50}

# %%
best_model = result.best_estimator_
y_train_predicted = best_model.predict_proba(X_train_origin)[:, 1]
y_test_predicted = best_model.predict_proba(X_test_origin)[:, 1]

# %%
from sklearn.metrics import roc_auc_score, roc_curve

train_auc = roc_auc_score(y_train, y_train_predicted)
test_auc = roc_auc_score(y_test, y_test_predicted)

plt.figure(figsize=(10,7))
plt.plot(*roc_curve(y_train, y_train_predicted)[:2], label='train AUC={:.4f}'.format(train_auc))
plt.plot(*roc_curve(y_test, y_test_predicted)[:2], label='test AUC={:.4f}'.format(test_auc))
legend_box = plt.legend(fontsize='large', framealpha=1).get_frame()
legend_box.set_facecolor("white")
legend_box.set_edgecolor("black")
plt.plot(np.linspace(0,1,100), np.linspace(0,1,100))
plt.show()

# %%
feature_importances = best_model.get_feature_importance(type='FeatureImportance')


sorted_indices = feature_importances.argsort()[::-1]
sorted_feature_importances = feature_importances[sorted_indices]

plt.figure(figsize=(10, 6))
plt.bar(range(len(sorted_feature_importances)), sorted_feature_importances)
plt.xticks(range(len(sorted_feature_importances)), sorted_indices)
plt.xlabel('Индексы признаков')
plt.ylabel('Значимость признаков')
plt.title('Значимость признаков в CatBoost')
plt.show()

# %%
print(cat_cols)
best_cat_cols = cat_cols.copy()
ignored_features = []

for index in sorted_indices[::-1]:
    if feature_importances[index] < 2:
        print("- ", cat_cols[index])
        ignored_features.append(index)
        del best_cat_cols[index]
# Out:
# ['Sex', 'IsSeniorCitizen', 'HasPartner', 'HasChild', 'HasPhoneService', 'HasMultiplePhoneNumbers', 'HasInternetService', 'HasOnlineSecurityService', 'HasOnlineBackup', 'HasDeviceProtection', 'HasTechSupportAccess', 'HasOnlineTV', 'HasMovieSubscription', 'HasContractPhone', 'IsBillingPaperless', 'PaymentMethod']
# -  PaymentMethod
# -  IsBillingPaperless
# -  HasMovieSubscription
# -  HasInternetService
# -  HasMultiplePhoneNumbers
# -  HasChild
# -  HasOnlineSecurityService

# %%
print(ignored_features)

#Лайфхак переучиваемся на полном наборе данных
best_model = catboost.CatBoostClassifier(
    cat_features=cat_cols,
    ignored_features=ignored_features,
    depth=result.best_params_["depth"],
    learning_rate=result.best_params_["learning_rate"],
    iterations=result.best_params_["iterations"])

best_model.fit(data.drop(target_col, axis=1), data[target_col])
# Out:
# [15, 14, 12, 6, 5, 3, 7]
# 0:	learn: 0.6622333	total: 5.52ms	remaining: 403ms
# 1:	learn: 0.6357502	total: 10.2ms	remaining: 367ms
# 2:	learn: 0.6130805	total: 13.2ms	remaining: 312ms
# 3:	learn: 0.5926238	total: 17.4ms	remaining: 304ms
# 4:	learn: 0.5743130	total: 22.6ms	remaining: 312ms
# 5:	learn: 0.5585282	total: 26.4ms	remaining: 299ms
# 6:	learn: 0.5446694	total: 31.7ms	remaining: 303ms
# 7:	learn: 0.5332197	total: 36.4ms	remaining: 301ms
# 8:	learn: 0.5219642	total: 40ms	remaining: 289ms
# 9:	learn: 0.5124392	total: 43.4ms	remaining: 278ms
# 10:	learn: 0.5037446	total: 46.9ms	remaining: 269ms
# 11:	learn: 0.4966133	total: 49.2ms	remaining: 254ms
# 12:	learn: 0.4896952	total: 52.7ms	remaining: 247ms
# 13:	learn: 0.4827079	total: 55ms	remaining: 236ms
# 14:	learn: 0.4767918	total: 56.3ms	remaining: 221ms
# 15:	learn: 0.4707059	total: 59.9ms	remaining: 217ms
# 16:	learn: 0.4665685	total: 61.4ms	remaining: 206ms
# 17:	learn: 0.4617517	total: 64.9ms	remaining: 202ms
# 18:	learn: 0.4585185	total: 66.1ms	remaining: 191ms
# 19:	learn: 0.4544224	total: 68.4ms	remaining: 185ms
# 20:	learn: 0.4509257	total: 71.9ms	remaining: 181ms
# 21:	learn: 0.4469930	total: 75.4ms	remaining: 178ms
# 22:	learn: 0.4435296	total: 78.8ms	remaining: 175ms
# 23:	learn: 0.4400909	total: 82.2ms	remaining: 171ms
# 24:	learn: 0.4375530	total: 84ms	remaining: 165ms
# 25:	learn: 0.4349033	total: 87.5ms	remaining: 162ms
# 26:	learn: 0.4323456	total: 91ms	remaining: 158ms
# 27:	learn: 0.4302123	total: 94.9ms	remaining: 156ms
# 28:	learn: 0.4279710	total: 98.4ms	remaining: 153ms
# 29:	learn: 0.4259342	total: 102ms	remaining: 149ms
# 30:	learn: 0.4242572	total: 105ms	remaining: 146ms
# 31:	learn: 0.4222789	total: 109ms	remaining: 143ms
# 32:	learn: 0.4210339	total: 111ms	remaining: 138ms
# 33:	learn: 0.4193586	total: 115ms	remaining: 135ms
# 34:	learn: 0.4180494	total: 118ms	remaining: 132ms
# 35:	learn: 0.4170412	total: 122ms	remaining: 129ms
# 36:	learn: 0.4164537	total: 124ms	remaining: 124ms
# 37:	learn: 0.4159947	total: 125ms	remaining: 119ms
# 38:	learn: 0.4151364	total: 127ms	remaining: 114ms
# 39:	learn: 0.4140416	total: 131ms	remaining: 111ms
# 40:	learn: 0.4126361	total: 134ms	remaining: 108ms
# 41:	learn: 0.4120656	total: 136ms	remaining: 103ms
# 42:	learn: 0.4109314	total: 139ms	remaining: 100ms
# 43:	learn: 0.4100518	total: 143ms	remaining: 97.2ms
# 44:	learn: 0.4095645	total: 146ms	remaining: 94.3ms
# 45:	learn: 0.4089268	total: 148ms	remaining: 90.2ms
# 46:	learn: 0.4078508	total: 152ms	remaining: 87.2ms
# 47:	learn: 0.4072249	total: 155ms	remaining: 84.1ms
# 48:	learn: 0.4066777	total: 159ms	remaining: 81ms
# 49:	learn: 0.4063518	total: 161ms	remaining: 77.1ms
# 50:	learn: 0.4055917	total: 168ms	remaining: 75.9ms
# 51:	learn: 0.4050951	total: 172ms	remaining: 72.7ms
# 52:	learn: 0.4046137	total: 175ms	remaining: 69.5ms
# 53:	learn: 0.4044296	total: 177ms	remaining: 65.6ms
# 54:	learn: 0.4040034	total: 181ms	remaining: 62.5ms
# 55:	learn: 0.4034480	total: 185ms	remaining: 59.6ms
# 56:	learn: 0.4033387	total: 187ms	remaining: 55.9ms
# 57:	learn: 0.4030403	total: 190ms	remaining: 52.4ms
# 58:	learn: 0.4024613	total: 193ms	remaining: 49.2ms
# 59:	learn: 0.4022054	total: 195ms	remaining: 45.5ms
# 60:	learn: 0.4018361	total: 198ms	remaining: 42.1ms
# 61:	learn: 0.4015630	total: 200ms	remaining: 38.7ms
# 62:	learn: 0.4013125	total: 203ms	remaining: 35.5ms
# 63:	learn: 0.4010176	total: 205ms	remaining: 32.1ms
# 64:	learn: 0.4008158	total: 207ms	remaining: 28.7ms
# 65:	learn: 0.4003241	total: 211ms	remaining: 25.6ms
# 66:	learn: 0.3998069	total: 215ms	remaining: 22.4ms
# 67:	learn: 0.3993528	total: 218ms	remaining: 19.2ms
# 68:	learn: 0.3987811	total: 221ms	remaining: 16.1ms
# 69:	learn: 0.3985433	total: 225ms	remaining: 12.9ms
# 70:	learn: 0.3984289	total: 228ms	remaining: 9.64ms
# 71:	learn: 0.3984030	total: 232ms	remaining: 6.43ms
# 72:	learn: 0.3979951	total: 235ms	remaining: 3.22ms
# 73:	learn: 0.3979037	total: 238ms	remaining: 0us

# %%
y_train_predicted = best_model.predict_proba(X_train_origin)[:, 1]
y_test_predicted = best_model.predict_proba(X_test_origin)[:, 1]

train_auc = roc_auc_score(y_train, y_train_predicted)
test_auc = roc_auc_score(y_test, y_test_predicted)

plt.figure(figsize=(10,7))
plt.plot(*roc_curve(y_train, y_train_predicted)[:2], label='train AUC={:.4f}'.format(train_auc))
plt.plot(*roc_curve(y_test, y_test_predicted)[:2], label='test AUC={:.4f}'.format(test_auc))
legend_box = plt.legend(fontsize='large', framealpha=1).get_frame()
legend_box.set_facecolor("white")
legend_box.set_edgecolor("black")
plt.plot(np.linspace(0,1,100), np.linspace(0,1,100))
plt.show()

# %% [markdown]
# Выпишите, какое лучшее качество и с какими параметрами вам удалось получить

# %% [markdown]
# ВАШ ОТВЕТ

# %% [markdown]
# # Предсказания

# %%
X_test = pd.read_csv('./test.csv')
submission = pd.read_csv('./submission.csv')
submission['Churn'] = best_model.predict_proba(X_test)[:,1]
submission.head
submission.to_csv('./my_submission.csv', index=False)

# %% [markdown]
# Лучшее решение отправьте в Stepik.
